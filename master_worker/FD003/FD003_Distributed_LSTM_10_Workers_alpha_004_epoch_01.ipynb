# %% [markdown]
# # Function Definitions

# %%
class LSTM:
    def __init__(self, input_size=340, output_size=101, n_h=100, seq_len=25, epochs=1, alpha=0.004, beta1=0.9,
                 beta2=0.999):
        self.input_size = input_size  # no. of unique characters in the training data
        self.output_size = output_size  # no. of RUL values in the dataset
        self.n_h = n_h  # no. of units in the hidden layer
        self.seq_len = seq_len  # no. of time steps, also size of mini batch
        self.epochs = epochs  # no. of training iterations
        self.alpha = alpha  # learning rate
        self.beta1 = beta1  # 1st momentum parameter
        self.beta2 = beta2  # 2nd momentum parameter

        # ----initialise weighs and biases----- #
        self.params = {}
        std = (1.0 / np.sqrt(self.input_size + self.n_h))  # Xavier initialisation

        # forget gate
        self.params["Wf"] = np.random.randn(self.n_h, self.n_h + self.input_size) * std
        self.params["bf"] = np.ones((self.n_h, 1))

        # input gate
        self.params["Wi"] = np.random.randn(self.n_h, self.n_h + self.input_size) * std
        self.params["bi"] = np.ones((self.n_h, 1))

        # cell gate
        self.params["Wc"] = np.random.randn(self.n_h, self.n_h + self.input_size) * std
        self.params["bc"] = np.ones((self.n_h, 1))

        # output gate
        self.params["Wo"] = np.random.randn(self.n_h, self.n_h + self.input_size) * std
        self.params["bo"] = np.ones((self.n_h, 1))

        # output
        self.params["Wv"] = np.random.randn(self.output_size, self.n_h) * (1.0 / np.sqrt(self.output_size))
        self.params["bv"] = np.ones((self.output_size, 1))

        # -----initialise gradients and Adam parameters-----#
        self.grads = {}
        self.adam_params = {}

        for key in self.params:
            self.grads["d" + key] = np.zeros_like(self.params[key])
            self.adam_params["m" + key] = np.zeros_like(self.params[key])
            self.adam_params["v" + key] = np.zeros_like(self.params[key])

        self.smooth_loss = -np.log(1.0 / self.output_size) * self.seq_len

        return

    def init_random_params(self):
        # ----initialise weighs and biases----- #
        self.params = {}
        std = (1.0 / np.sqrt(self.input_size + self.n_h))  # Xavier initialisation

        # forget gate
        self.params["Wf"] = np.random.randn(self.n_h, self.n_h + self.input_size) * std
        self.params["bf"] = np.ones((self.n_h, 1))

        # input gate
        self.params["Wi"] = np.random.randn(self.n_h, self.n_h + self.input_size) * std
        self.params["bi"] = np.ones((self.n_h, 1))

        # cell gate
        self.params["Wc"] = np.random.randn(self.n_h, self.n_h + self.input_size) * std
        self.params["bc"] = np.ones((self.n_h, 1))

        # output gate
        self.params["Wo"] = np.random.randn(self.n_h, self.n_h + self.input_size) * std
        self.params["bo"] = np.ones((self.n_h, 1))

        # output
        self.params["Wv"] = np.random.randn(self.output_size, self.n_h) * (1.0 / np.sqrt(self.output_size))
        self.params["bv"] = np.ones((self.output_size, 1))

        return self.params

    # Firstly, we will compute the sigmoid activation used at the forget, input and output gate layers, and the softmax
    # activation used at the output layer. Tanh activation is also needed but numpy.tanh is used instead.

    def sigmoid(self, x):
        """
        Smoothes out values in the range of [0,1]
        """
        return 1 / (1 + np.exp(-x))

    def softmax(self, x):
        """
        Normalizes output into a probability distribution
        """
        e_x = np.exp(x - np.max(x))  # max(x) subtracted for numerical stability
        # e_x = np.exp(x) # Normal softmax activation function
        return e_x / np.sum(e_x, axis=0)

    # Although exploding gradients is not as prevalent for LSTMs as for RNNs, we will limit the gradients to a
    # conservative value using clip_grads. After back propagating through all LSTM cells, we will reset the
    # gradients using reset_grads.

    def clip_grads(self):
        """
        Limits the magnitude of gradients to avoid exploding gradients
        """
        for key in self.grads:
            np.clip(self.grads[key], -5, 5, out=self.grads[key])
        return

    def reset_grads(self):
        """
        Resets gradients to zero before each backpropagation
        """
        for key in self.grads:
            self.grads[key].fill(0)
        return

    # The last utility function that we will create is for updating the weights using Adam. Note that the weights are
    # updated using the accumulated gradients for all time steps.

    def update_params(self, batch_num):
        """
        Updates parameters with Adam
        """
        for key in self.params:
            self.adam_params["m" + key] = self.adam_params["m" + key] * self.beta1 + \
                                          (1 - self.beta1) * self.grads["d" + key]
            self.adam_params["v" + key] = self.adam_params["v" + key] * self.beta2 + \
                                          (1 - self.beta2) * self.grads["d" + key] ** 2

            m_correlated = self.adam_params["m" + key] / (1 - self.beta1 ** batch_num)
            v_correlated = self.adam_params["v" + key] / (1 - self.beta2 ** batch_num)
            self.params[key] -= self.alpha * m_correlated / (np.sqrt(v_correlated) + 1e-8)
        return

    # Forward propagation for a time-step
    # We will propagate forwards through each LSTM cell using forward_step
    # A LSTM cell depends on the previous cell’s state (like Neural Networks). forward_step therefore takes as input
    # the previous hidden state (h_prev) and previous cell state (c_prev). At the beginning of every training iteration,
    # the previous hidden states are initialised to zero (i.e. at t = -1), but for subsequent time-steps, they
    # correspond to the hidden states at t-1, where t is the current time-step.

    def forward_step(self, x, h_prev, c_prev):
        """
        Implements the forward propagation for one time step
        """
        z = np.row_stack((h_prev, x))  # row_stack can also be used

        f = self.sigmoid(np.dot(self.params["Wf"], z) + self.params["bf"])  # [n_h, 1]
        i = self.sigmoid(np.dot(self.params["Wi"], z) + self.params["bi"])  # [n_h, 1]
        c_bar = np.tanh(np.dot(self.params["Wc"], z) + self.params["bc"])  # [n_h, 1]

        c = f * c_prev + i * c_bar  # [n_h, 1]
        o = self.sigmoid(np.dot(self.params["Wo"], z) + self.params["bo"])  # [n_h, 1]
        h = o * np.tanh(c)  # [n_h, 1]

        v = np.dot(self.params["Wv"], h) + self.params["bv"]  # [output_size, n_h] @ [n_h, 1] + [
        # output_size, 1] = [output_size, 1]
        y_hat = self.softmax(v)  # [output_size, 1]
        # print("y_hat from softmax function in forward step", y_hat)

        return y_hat, v, h, o, c, c_bar, i, f, z

    # Backward propagation for a time-step
    # After forward propagation, we will pass the updated values of the last LSTM cell to backward_step and propagate
    # the gradients backwards to the first LSTM cell.
    # dh_next and dc_next are initialised to zero at t = -1, but take the values of dh_prev and dc_prev that
    # backward_step returns in subsequent time steps.
    # In addition, it is worth clarifying:

    # 1. As weights are shared by all time steps, the weight gradients are accumulated.
    # 2. We are adding dh_next to dh, because as Figure 1 shows, h is branched in forward propagation in the softmax
    # output layer and the next LSTM cell, where it is concatenated with x. Therefore, there are two gradients flowing
    # back. This applies to dc as well.
    # 3. There are four gradients flowing towards the input layer from the gates, therefore dz is the summation of
    # those gradients.

    def backward_step(self, y, y_hat, dh_next, dc_next, c_prev, z, f, i, c_bar, c, o, h):
        dv = np.copy(y_hat)
        dv[y] -= 1  # dJ/dv = y_hat - y

        # print("-------------------------------------------------------------------------------------------------------")
        # print("y in back propagation:", y)
        # print("dv[y] from backward_step", dv)

        # Output bach propagation
        self.grads["dWv"] += np.dot(dv, h.T)
        self.grads["dbv"] += dv

        # Hidden state back propagation
        dh = np.dot(self.params["Wv"].T, dv)
        dh += dh_next

        do = dh * np.tanh(c)
        da_o = do * o * (1 - o)
        self.grads["dWo"] += np.dot(da_o, z.T)
        self.grads["dbo"] += da_o

        # Cell states back propagation
        dc = dh * o * (1 - np.tanh(c) ** 2)
        dc += dc_next

        dc_bar = dc * i
        da_c = dc_bar * (1 - c_bar ** 2)
        self.grads["dWc"] += np.dot(da_c, z.T)
        self.grads["dbc"] += da_c

        # Input gate back propagation
        di = dc * c_bar
        da_i = di * i * (1 - i)
        self.grads["dWi"] += np.dot(da_i, z.T)
        self.grads["dbi"] += da_i

        # Forget gate back propagation
        df = dc * c_prev
        da_f = df * f * (1 - f)
        self.grads["dWf"] += np.dot(da_f, z.T)
        self.grads["dbf"] += da_f

        # Input back propagation
        dz = (np.dot(self.params["Wf"].T, da_f)\
             + np.dot(self.params["Wi"].T, da_i)\
             + np.dot(self.params["Wo"].T, da_o) \
             + np.dot(self.params["Wc"].T, da_c))

        dh_prev = dz[:self.n_h, :]
        dc_prev = f * dc

        return dh_prev, dc_prev

    # Forward and backward propagation for all time-steps
    # The forward and backward propagation steps will be executed within the forward_backward function. Here, we iterate
    # over all time steps and store the results for each time step in dictionaries. In the forward propagation loop,
    # we also accumulate the cross entropy loss.

    # forward_backward exports the cross entropy loss of the training batch, in addition to the hidden and cell states
    # of the last layer which are fed to the first LSTM cell as hprev and prev of the next training batch.

    def forward_backward(self, x_batch, y_batch, h_prev, c_prev):
        x, z = {}, {}
        f, i, c_bar, c, o = {}, {}, {}, {}, {}
        y_hat, v, h = {}, {}, {}

        # Values at t= - 1
        h[-1] = h_prev
        c[-1] = c_prev

        loss = 0
        for t in range(self.seq_len):
            x[t] = x_batch[t].reshape(-1, 1)

            y_hat[t], v[t], h[t], o[t], c[t], c_bar[t], i[t], f[t], z[t] = \
                self.forward_step(x[t], h[t - 1], c[t - 1])

            loss += -np.log(y_hat[t][y_batch[t], 0])

        self.reset_grads()

        dh_next = np.zeros_like(h[0])
        dc_next = np.zeros_like(c[0])

        for t in reversed(range(self.seq_len)):
            dh_next, dc_next = self.backward_step(y_batch[t], y_hat[t], dh_next, dc_next, c[t - 1], z[t], f[t], i[t],
                                                  c_bar[t], c[t], o[t], h[t])

        return loss, h[self.seq_len - 1], c[self.seq_len - 1]


    def predict(self, x_batch, h_prev, c_prev):
        x, z = {}, {}
        f, i, c_bar, c, o = {}, {}, {}, {}, {}
        y_hat, v, h = {}, {}, {}
        y_hat_pred = np.zeros((self.seq_len, 1))


        # Values at t= - 1
        h[-1] = h_prev
        c[-1] = c_prev

        loss = 0
        for t in range(self.seq_len):
            x[t] = x_batch[t].reshape(-1, 1)

            y_hat[t], v[t], h[t], o[t], c[t], c_bar[t], i[t], f[t], z[t] = \
                self.forward_step(x[t], h[t - 1], c[t - 1])

            y_hat_pred[t, :] = np.argmax(y_hat[t])

            loss += -np.log(y_hat_pred[t, :])

        return y_hat_pred, loss, h[self.seq_len - 1], c[self.seq_len - 1]

    # Gradient checking: To check the backpropagation calculation, we can numerically approximate the gradient at a
    # point and compare it to the model’s back propagation gradient.

    def gradient_check(self, x, y, h_prev, c_prev, num_checks=10, delta=1e-6):
        """
        Checks the magnitude of gradients against expected approximate values
        """
        print("**********************************")
        print("Gradient check...\n")

        _, _, _ = self.forward_backward(x, y, h_prev, c_prev)
        grads_numerical = self.grads

        for key in self.params:
            print("---------", key, "---------")
            test = True

            dims = self.params[key].shape
            grad_numerical = 0
            grad_analytical = 0

            for _ in range(num_checks):  # sample 10 neurons

                idx = int(uniform(0, self.params[key].size))
                old_val = self.params[key].flat[idx]

                self.params[key].flat[idx] = old_val + delta
                J_plus, _, _ = self.forward_backward(x, y, h_prev, c_prev)

                self.params[key].flat[idx] = old_val - delta
                J_minus, _, _ = self.forward_backward(x, y, h_prev, c_prev)

                self.params[key].flat[idx] = old_val

                grad_numerical += (J_plus - J_minus) / (2 * delta)
                grad_analytical += grads_numerical["d" + key].flat[idx]

            grad_numerical /= num_checks
            grad_analytical /= num_checks

            rel_error = abs(grad_analytical - grad_numerical) / abs(grad_analytical + grad_numerical)

            if rel_error > 1e-2:
                if not (grad_analytical < 1e-6 and grad_numerical < 1e-6):
                    test = False
                    assert (test)

            print('Approximate: \t%e, Exact: \t%e =>  Error: \t%e' % (grad_numerical, grad_analytical, rel_error))
        print("\nTest successful!")
        print("**********************************\n")
        return

    # we define the function to train the model. train takes as input a sequence of input image data and outputs a list
    # of losses for each training batch (J) as well as the trained parameters.
    # In order to speed up training, we will train our data in batches. The number of batches (num_batches) is given by
    # the total number of inputs data for each agent (len(X[i])) divided by the seq_len, which is user-defined.
    # The input text goes through the following processing steps:

    # 1. Firstly, we trim the input data that don’t form a full sequence
    # 2. When we iterate over each training batch, we slice the input data in batches of size seq_len
    # 3.

    def train(self, X, Y, params ,verbose=True):
        """
        Main method of the LSTM class where training takes place
        """
        self.params = params
        J = []  # to store losses

        num_batches = len(X) // self.seq_len
        X_trimmed = X[: num_batches * self.seq_len]  # trim input to have full sequences
        Y_trimmed = Y[: num_batches * self.seq_len]  # trim output to have full sequences

        for epoch in range(self.epochs):
            h_prev = np.zeros((self.n_h, 1))
            c_prev = np.zeros((self.n_h, 1))

            for j in range(0, len(X_trimmed), self.seq_len):
                # prepare batches
                x_batch = X_trimmed[j: j + self.seq_len]
                y_batch = Y_trimmed[j: j + self.seq_len]

                loss, h_prev, c_prev = self.forward_backward(x_batch, y_batch, h_prev, c_prev)

                # smooth out loss and store in list
                self.smooth_loss = self.smooth_loss * 0.999 + loss * 0.001
                J.append(self.smooth_loss)

                # check gradients
            #    if epoch == 0 and j == 0:
            #        self.gradient_check(x_batch, y_batch, h_prev, c_prev, num_checks=10, delta=1e-7)

                self.clip_grads()

                batch_num = epoch * self.epochs + j / self.seq_len + 1
                self.update_params(batch_num)

                # print out loss
                if verbose and j == len(X_trimmed) - 2 * self.seq_len:
                    print('Epoch', epoch, '\tBatch:', j, "-", j + self.seq_len, '\tLoss:',
                          np.round(self.smooth_loss, 2))

        return J, self.params

    def test_pred(self, X_test, params):
        """
        Calculate the accuracy of the model with test data
        """
        self.params = params
        Y_hat_pred = np.ones(shape=(len(X_test), 1))

        num_batches = len(X_test) // self.seq_len
        X_trimmed = X_test[: num_batches * self.seq_len]  # trim input to have full sequences

        h_prev = np.zeros((self.n_h, 1))
        c_prev = np.zeros((self.n_h, 1))

        for j in range(0, len(X_trimmed), self.seq_len):
            # prepare batches
            x_batch = X_trimmed[j: j + self.seq_len]

            y_hat_pred, loss, h_prev, c_prev = self.predict(x_batch, h_prev, c_prev)

            Y_hat_pred[j: j + self.seq_len, :] = y_hat_pred

        return Y_hat_pred

    def test_loss(self, X_test, params, verbose=True):
        """
        Calculate the accuracy of the model with test data
        """
        self.params = params
        J_test = []  # to store losses
        Y_hat_pred = np.ones(shape=(len(X_test), 1))

        num_batches = len(X_test) // self.seq_len
        X_trimmed = X_test[: num_batches * self.seq_len]  # trim input to have full sequences

        for epoch in range(self.epochs):
            h_prev = np.zeros((self.n_h, 1))
            c_prev = np.zeros((self.n_h, 1))
            print('Epoch', epoch)
            for j in range(0, len(X_trimmed), self.seq_len):
                # prepare batches
                x_batch = X_trimmed[j: j + self.seq_len]

                y_hat_pred, loss, h_prev, c_prev = self.predict(x_batch, h_prev, c_prev)

                # smooth out loss and store in list
                self.smooth_loss = self.smooth_loss * 0.999 + loss * 0.001
                J_test.append(self.smooth_loss)

                Y_hat_pred[j: j + self.seq_len, :] = y_hat_pred

                # print out train loss
                if verbose and j == len(X_trimmed) - 2 * self.seq_len:
                    print('Epoch', epoch, '\tBatch:', j, "-", j + self.seq_len, '\tTrain_Loss:',
                          np.round(self.smooth_loss, 2))

        return J_test

# %%
# function to reshape features into (samples, time steps, features)
def gen_sequence(id_df, seq_length, seq_cols):
    #Only sequences that meet the window-length are considered, no padding is used. This means for testing
    #we need to drop those which are below the window-length. An alternative would be to pad sequences so that
    #we can use shorter ones """
    data_array = id_df[seq_cols].values
    num_elements = data_array.shape[0]
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_array[start:stop, :]

# %%
# function to generate labels
def gen_labels(id_df, seq_length, label):
    data_array = id_df[label].values
    num_elements = data_array.shape[0]
    return data_array[seq_length:num_elements, :]

# %%
# function to reshape features into (samples, time steps, features)
def gen_sequence_reshape(id_df, seq_length, seq_cols):
    """ Only sequences that meet the window-length are considered, no padding is used. This means for testing
    we need to drop those which are below the window-length. An alternative would be to pad sequences so that
    we can use shorter ones """
    data_array = id_df[seq_cols].values
    num_elements = data_array.shape[0]
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_array[start:stop, :].reshape(-1)

# %%
# function to reshape features into (samples, time steps, features)
def gen_sequence_reshape_append1(id_df, seq_length, seq_cols):
    """ Only sequences that meet the window-length are considered, no padding is used. This means for testing
    we need to drop those which are below the window-length. An alternative would be to pad sequences so that
    we can use shorter ones """
    data_array = id_df[seq_cols].values
    num_elements = data_array.shape[0]
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield np.append(data_array[start:stop, :].reshape(-1), 1)

# %% [markdown]
# # Main

# %%
# input_size = 35 * 17 + 1 = 596 The input ton the LSTM, Z, has dimensions [input_size + n_h, 1]. Since the LSTM
# layer want to output n_h neurons, each weight should be of size [n_h, input_size + n_h] and each bias of size
# [n_h, 1]. Exception is the weight and bias at the output softmax layer (Wv, bv). The resulting output will be a
# probability distribution over all possible RUL in the dataset, therefore of size [output_size, 1], hence Wv should be
# of size [output_size, n_h] and bv of size [output_size, 1]
import numpy as np
import pickle
import os
# from model import *

# Import libraries
from random import uniform
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

import time
import math
import sys
import random

# the "resource" library is not available on windows.
# if it can be imported, we can use it! For example, while running on google colab
try:
    import resource

    print("Succesfully imported 'resource' package")
except:
    print("Failed on importing 'resource' package, continuing wihtout it!")
# Out:
# Failed on importing 'resource' package, continuing wihtout it!

# %% [markdown]
# # Read training data

# %%
# read training data
train_df = pd.read_csv('train_FD003.txt', sep=" ", header=None)
train_df.drop(train_df.columns[[26, 27]], axis=1, inplace=True)
train_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                    's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                    's15', 's16', 's17', 's18', 's19', 's20', 's21']

# %% [markdown]
# ### Remove the features which has low prognosability
# ### This part has been calculated by Matlab and the signals was selected

# %%
# remove the features which has low prognosability
# this part has been calculated by Matlab and the signals was selected
train_df.drop(labels=['setting3', 's1', 's5', 's6', 's10', 's16', 's18', 's19'], axis=1, inplace=True)
train_df.head()
# Out:
#    id  cycle  setting1  setting2      s2       s3       s4      s7       s8  \
# 0   1      1   -0.0005    0.0004  642.36  1583.23  1396.84  553.97  2387.96
# 1   1      2    0.0008   -0.0003  642.50  1584.69  1396.89  554.55  2388.00
# 2   1      3   -0.0014   -0.0002  642.18  1582.35  1405.61  554.43  2388.03
# 3   1      4   -0.0020    0.0001  642.92  1585.61  1392.27  555.21  2388.00
# 4   1      5    0.0016    0.0000  641.68  1588.63  1397.65  554.74  2388.04
#
#         s9    s11     s12      s13      s14     s15  s17    s20      s21
# 0  9062.17  47.30  522.31  2388.01  8145.32  8.4246  391  39.11  23.3537
# 1  9061.78  47.23  522.42  2388.03  8152.85  8.4403  392  38.99  23.4491
# 2  9070.23  47.22  522.03  2388.00  8150.17  8.3901  391  38.85  23.3669
# 3  9064.57  47.24  522.49  2388.08  8146.56  8.3878  392  38.96  23.2951
# 4  9076.14  47.15  522.58  2388.03  8147.80  8.3869  392  39.14  23.4583

# %% [markdown]
# ### Data Preprocessing
# ### Data Labeling - generate column RUL

# %%
# Data Preprocessing
# Data Labeling - generate column RUL
rul = pd.DataFrame(train_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
train_df = train_df.merge(rul, on=['id'], how='left')
train_df['RUL'] = train_df['max'] - train_df['cycle']
train_df.drop('max', axis=1, inplace=True)
train_df.head()
# Out:
#    id  cycle  setting1  setting2      s2       s3       s4      s7       s8  \
# 0   1      1   -0.0005    0.0004  642.36  1583.23  1396.84  553.97  2387.96
# 1   1      2    0.0008   -0.0003  642.50  1584.69  1396.89  554.55  2388.00
# 2   1      3   -0.0014   -0.0002  642.18  1582.35  1405.61  554.43  2388.03
# 3   1      4   -0.0020    0.0001  642.92  1585.61  1392.27  555.21  2388.00
# 4   1      5    0.0016    0.0000  641.68  1588.63  1397.65  554.74  2388.04
#
#         s9    s11     s12      s13      s14     s15  s17    s20      s21  RUL
# 0  9062.17  47.30  522.31  2388.01  8145.32  8.4246  391  39.11  23.3537  258
# 1  9061.78  47.23  522.42  2388.03  8152.85  8.4403  392  38.99  23.4491  257
# 2  9070.23  47.22  522.03  2388.00  8150.17  8.3901  391  38.85  23.3669  256
# 3  9064.57  47.24  522.49  2388.08  8146.56  8.3878  392  38.96  23.2951  255
# 4  9076.14  47.15  522.58  2388.03  8147.80  8.3869  392  39.14  23.4583  254

# %% [markdown]
# ### Generate label columns for training data

# %%
# generate label columns for training data
w1 = 30
w0 = 15
train_df['label1'] = np.where(train_df['RUL'] <= w1, 1, -1)
train_df['label2'] = train_df['label1']
train_df.loc[train_df['RUL'] <= w0, 'label2'] = 2
train_df.head()
# Out:
#    id  cycle  setting1  setting2      s2       s3       s4      s7       s8  \
# 0   1      1   -0.0005    0.0004  642.36  1583.23  1396.84  553.97  2387.96
# 1   1      2    0.0008   -0.0003  642.50  1584.69  1396.89  554.55  2388.00
# 2   1      3   -0.0014   -0.0002  642.18  1582.35  1405.61  554.43  2388.03
# 3   1      4   -0.0020    0.0001  642.92  1585.61  1392.27  555.21  2388.00
# 4   1      5    0.0016    0.0000  641.68  1588.63  1397.65  554.74  2388.04
#
#         s9  ...     s12      s13      s14     s15  s17    s20      s21  RUL  \
# 0  9062.17  ...  522.31  2388.01  8145.32  8.4246  391  39.11  23.3537  258
# 1  9061.78  ...  522.42  2388.03  8152.85  8.4403  392  38.99  23.4491  257
# 2  9070.23  ...  522.03  2388.00  8150.17  8.3901  391  38.85  23.3669  256
# 3  9064.57  ...  522.49  2388.08  8146.56  8.3878  392  38.96  23.2951  255
# 4  9076.14  ...  522.58  2388.03  8147.80  8.3869  392  39.14  23.4583  254
#
#    label1  label2
# 0      -1      -1
# 1      -1      -1
# 2      -1      -1
# 3      -1      -1
# 4      -1      -1
#
# [5 rows x 21 columns]

# %% [markdown]
# ### MinMax normalization. In the Predictive Maintenance Template , cycle column is also used for training so I will also include the cycle column. Here, I normalize the columns in the training data

# %%
# MinMax normalization
# In the Predictive Maintenance Template , cycle column is also used for training so we will also include the cycle
# column.
# Here, we normalize the columns in the training data.
train_df['cycle_norm'] = train_df['cycle']
cols_normalize = train_df.columns.difference(['id', 'cycle', 'RUL', 'label1', 'label2'])
min_max_scaler = MinMaxScaler()
norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_df[cols_normalize]),
                             columns=cols_normalize,
                             index=train_df.index)
join_df = train_df[train_df.columns.difference(cols_normalize)].join(norm_train_df)
train_df = join_df.reindex(columns=train_df.columns)
train_df.head()
# Out:
#    id  cycle  setting1  setting2        s2        s3        s4        s7  \
# 0   1      1  0.470930  0.769231  0.355972  0.370523  0.308580  0.208812
# 1   1      2  0.546512  0.230769  0.388759  0.399100  0.309360  0.236590
# 2   1      3  0.418605  0.307692  0.313817  0.353298  0.445398  0.230843
# 3   1      4  0.383721  0.538462  0.487119  0.417107  0.237285  0.268199
# 4   1      5  0.593023  0.461538  0.196721  0.476218  0.321217  0.245690
#
#          s8        s9  ...       s13       s14       s15       s17       s20  \
# 0  0.623529  0.204233  ...  0.642857  0.239116  0.647755  0.272727  0.559524
# 1  0.647059  0.202431  ...  0.654762  0.278567  0.685659  0.363636  0.488095
# 2  0.664706  0.241484  ...  0.636905  0.264526  0.564462  0.272727  0.404762
# 3  0.647059  0.215326  ...  0.684524  0.245612  0.558909  0.363636  0.470238
# 4  0.670588  0.268799  ...  0.654762  0.252109  0.556736  0.363636  0.577381
#
#         s21  RUL  label1  label2  cycle_norm
# 0  0.446331  258      -1      -1    0.000000
# 1  0.534836  257      -1      -1    0.001908
# 2  0.458577  256      -1      -1    0.003817
# 3  0.391966  255      -1      -1    0.005725
# 4  0.543371  254      -1      -1    0.007634
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Clip Response. This step is optional. In order for network to focus on the part of the data where engines are more likely to fail (end of the engine's life), clip the responses at the threshold of 150. This makes the network treat instances with higher RUL values as equal.

# %%
# Clip Response
# This step is optional. In order for network to focus on the part of the data where engines are more likely to fail
# (end of the engine's life), clip the responses at the threshold of 150. This makes the network treat instances with
# higher RUL values as equal.
clipResponse = True
if clipResponse:
    rulThreshold = 100
    for i in range(len(train_df['RUL'])):
        train_df.loc[i, 'RUL'] = min(train_df.loc[i, 'RUL'], rulThreshold)
train_df.head()

train_df = train_df.sort_values(['id', 'cycle'])
train_df.head()
train_df.shape
# Out:
# (24720, 22)

# %% [markdown]
# # Read test data

# %%
# read test data
test_df = pd.read_csv('test_FD003.txt', sep=" ", header=None)
test_df.drop(test_df.columns[[26, 27]], axis=1, inplace=True)
test_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                   's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                   's15', 's16', 's17', 's18', 's19', 's20', 's21']
test_df.head()
# Out:
#    id  cycle  setting1  setting2  setting3      s1      s2       s3       s4  \
# 0   1      1   -0.0017   -0.0004     100.0  518.67  641.94  1581.93  1396.93
# 1   1      2    0.0006   -0.0002     100.0  518.67  642.02  1584.86  1398.90
# 2   1      3    0.0014   -0.0003     100.0  518.67  641.68  1581.78  1391.92
# 3   1      4    0.0027    0.0001     100.0  518.67  642.20  1584.53  1395.34
# 4   1      5   -0.0001    0.0001     100.0  518.67  642.46  1589.03  1395.86
#
#       s5  ...     s12      s13      s14     s15   s16  s17   s18    s19  \
# 0  14.62  ...  521.89  2387.94  8133.48  8.3760  0.03  391  2388  100.0
# 1  14.62  ...  521.85  2388.01  8137.44  8.4062  0.03  391  2388  100.0
# 2  14.62  ...  522.10  2387.94  8138.25  8.3553  0.03  391  2388  100.0
# 3  14.62  ...  522.45  2387.96  8137.07  8.3709  0.03  392  2388  100.0
# 4  14.62  ...  521.91  2387.97  8134.20  8.4146  0.03  391  2388  100.0
#
#      s20      s21
# 0  39.07  23.4468
# 1  39.04  23.4807
# 2  39.10  23.4244
# 3  38.97  23.4782
# 4  39.09  23.3950
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Remove the features which has low prognosability like train_df dataset. this part has been calculated by Matlab and the signals was selected

# %%
# remove the features which has low prognosability like train_df dataset
# this part has been calculated by Matlab and the signals was selected
test_df.drop(labels=['setting3', 's1', 's5', 's6', 's10', 's16', 's18', 's19'], axis=1, inplace=True)
test_df.head()
# Out:
#    id  cycle  setting1  setting2      s2       s3       s4      s7       s8  \
# 0   1      1   -0.0017   -0.0004  641.94  1581.93  1396.93  554.56  2387.93
# 1   1      2    0.0006   -0.0002  642.02  1584.86  1398.90  554.10  2387.94
# 2   1      3    0.0014   -0.0003  641.68  1581.78  1391.92  554.41  2387.97
# 3   1      4    0.0027    0.0001  642.20  1584.53  1395.34  554.58  2387.94
# 4   1      5   -0.0001    0.0001  642.46  1589.03  1395.86  554.16  2388.01
#
#         s9    s11     s12      s13      s14     s15  s17    s20      s21
# 0  9048.65  47.09  521.89  2387.94  8133.48  8.3760  391  39.07  23.4468
# 1  9046.53  47.08  521.85  2388.01  8137.44  8.4062  391  39.04  23.4807
# 2  9054.92  47.15  522.10  2387.94  8138.25  8.3553  391  39.10  23.4244
# 3  9055.04  47.26  522.45  2387.96  8137.07  8.3709  392  38.97  23.4782
# 4  9048.59  46.94  521.91  2387.97  8134.20  8.4146  391  39.09  23.3950

# %% [markdown]
# ### Read ground truth data

# %%
truth_df = pd.read_csv('RUL_FD003.txt', sep=" ", header=None)
truth_df.drop(truth_df.columns[[1]], axis=1, inplace=True)
truth_df.head()
# Out:
#      0
# 0   44
# 1   51
# 2   27
# 3  120
# 4  101

# %% [markdown]
# ### Next, I prepare the test data. I first normalize the test data using the parameters from the MinMax normalization applied on the training data.

# %%
# Next, we prepare the test data. We first normalize the test data using the parameters from the MinMax normalization
# applied on the training data.
test_df['cycle_norm'] = test_df['cycle']
norm_test_df = pd.DataFrame(min_max_scaler.transform(test_df[cols_normalize]),
                            columns=cols_normalize,
                            index=test_df.index)
test_join_df = test_df[test_df.columns.difference(cols_normalize)].join(norm_test_df)
test_df = test_join_df.reindex(columns=test_df.columns)
test_df = test_df.reset_index(drop=True)
test_df.head()
# Out:
#    id  cycle  setting1  setting2        s2        s3        s4        s7  \
# 0   1      1  0.401163  0.153846  0.257611  0.345077  0.309984  0.237069
# 1   1      2  0.534884  0.307692  0.276347  0.402427  0.340718  0.215038
# 2   1      3  0.581395  0.230769  0.196721  0.342141  0.231825  0.229885
# 3   1      4  0.656977  0.538462  0.318501  0.395968  0.285179  0.238027
# 4   1      5  0.494186  0.538462  0.379391  0.484048  0.293292  0.217912
#
#          s8        s9       s11       s12       s13       s14       s15  \
# 0  0.605882  0.141748  0.228571  0.209883  0.601190  0.177084  0.530420
# 1  0.611765  0.131950  0.222857  0.207845  0.642857  0.197831  0.603332
# 2  0.629412  0.170726  0.262857  0.220581  0.601190  0.202075  0.480444
# 3  0.611765  0.171281  0.325714  0.238411  0.613095  0.195892  0.518107
# 4  0.652941  0.141471  0.142857  0.210902  0.619048  0.180856  0.623612
#
#         s17       s20       s21  cycle_norm
# 0  0.272727  0.535714  0.532702    0.000000
# 1  0.272727  0.517857  0.564153    0.001908
# 2  0.272727  0.553571  0.511921    0.003817
# 3  0.363636  0.476190  0.561833    0.005725
# 4  0.272727  0.547619  0.484646    0.007634

# %% [markdown]
# ### Next, I use the ground truth dataset to generate labels for the test data.
# ### Generate column max for test data

# %%
# Next, we use the ground truth dataset to generate labels for the test data.
# generate column max for test data
rul = pd.DataFrame(test_df.groupby('id')['cycle'].max()).reset_index()
rul.columns = ['id', 'max']
truth_df.columns = ['more']
truth_df['id'] = truth_df.index + 1
truth_df['max'] = rul['max'] + truth_df['more']
truth_df.drop('more', axis=1, inplace=True)

# %% [markdown]
# ### Generate RUL for test data

# %%
test_df = test_df.merge(truth_df, on=['id'], how='left')
test_df['RUL'] = test_df['max'] - test_df['cycle']
test_df.drop('max', axis=1, inplace=True)
test_df.head()
# Out:
#    id  cycle  setting1  setting2        s2        s3        s4        s7  \
# 0   1      1  0.401163  0.153846  0.257611  0.345077  0.309984  0.237069
# 1   1      2  0.534884  0.307692  0.276347  0.402427  0.340718  0.215038
# 2   1      3  0.581395  0.230769  0.196721  0.342141  0.231825  0.229885
# 3   1      4  0.656977  0.538462  0.318501  0.395968  0.285179  0.238027
# 4   1      5  0.494186  0.538462  0.379391  0.484048  0.293292  0.217912
#
#          s8        s9       s11       s12       s13       s14       s15  \
# 0  0.605882  0.141748  0.228571  0.209883  0.601190  0.177084  0.530420
# 1  0.611765  0.131950  0.222857  0.207845  0.642857  0.197831  0.603332
# 2  0.629412  0.170726  0.262857  0.220581  0.601190  0.202075  0.480444
# 3  0.611765  0.171281  0.325714  0.238411  0.613095  0.195892  0.518107
# 4  0.652941  0.141471  0.142857  0.210902  0.619048  0.180856  0.623612
#
#         s17       s20       s21  cycle_norm  RUL
# 0  0.272727  0.535714  0.532702    0.000000  276
# 1  0.272727  0.517857  0.564153    0.001908  275
# 2  0.272727  0.553571  0.511921    0.003817  274
# 3  0.363636  0.476190  0.561833    0.005725  273
# 4  0.272727  0.547619  0.484646    0.007634  272

# %% [markdown]
# ### Clip Response on test dataset

# %%
# Clip Response on test dataset This step is optional. In order for network to focus on the part of the data
# where engines are more likely to fail (end of the engine's life), clip the responses at the threshold of 150.
# This makes the network treat instances with higher RUL values as equal.
clipResponse_dataset = True
if clipResponse_dataset:
    rulThreshold = 100
    for i in range(len(test_df['RUL'])):
        test_df.loc[i, 'RUL'] = min(test_df.loc[i, 'RUL'], rulThreshold)
test_df.head()
# Out:
#    id  cycle  setting1  setting2        s2        s3        s4        s7  \
# 0   1      1  0.401163  0.153846  0.257611  0.345077  0.309984  0.237069
# 1   1      2  0.534884  0.307692  0.276347  0.402427  0.340718  0.215038
# 2   1      3  0.581395  0.230769  0.196721  0.342141  0.231825  0.229885
# 3   1      4  0.656977  0.538462  0.318501  0.395968  0.285179  0.238027
# 4   1      5  0.494186  0.538462  0.379391  0.484048  0.293292  0.217912
#
#          s8        s9       s11       s12       s13       s14       s15  \
# 0  0.605882  0.141748  0.228571  0.209883  0.601190  0.177084  0.530420
# 1  0.611765  0.131950  0.222857  0.207845  0.642857  0.197831  0.603332
# 2  0.629412  0.170726  0.262857  0.220581  0.601190  0.202075  0.480444
# 3  0.611765  0.171281  0.325714  0.238411  0.613095  0.195892  0.518107
# 4  0.652941  0.141471  0.142857  0.210902  0.619048  0.180856  0.623612
#
#         s17       s20       s21  cycle_norm  RUL
# 0  0.272727  0.535714  0.532702    0.000000  100
# 1  0.272727  0.517857  0.564153    0.001908  100
# 2  0.272727  0.553571  0.511921    0.003817  100
# 3  0.363636  0.476190  0.561833    0.005725  100
# 4  0.272727  0.547619  0.484646    0.007634  100

# %% [markdown]
# ### Generate label columns w0 and w1 for test data

# %%
test_df['label1'] = np.where(test_df['RUL'] <= w1, 1, -1)
test_df['label2'] = test_df['label1']
test_df.loc[test_df['RUL'] <= w0, 'label2'] = 2
test_df.head()
test_df.shape
# Out:
# (16596, 22)

# %%
column_order = ['id', 'cycle', 'setting1', 'setting2', 's2', 's3', 's4', 's7', 's8', 's9', 's11', 's12', 's13',
            's14', 's15', 's17', 's20', 's21', 'RUL', 'label1', 'label2', 'cycle_norm']

test_df = test_df.reindex(columns = column_order)

# %% [markdown]
# ### Sliding window over the input data

# %%
sequence_length = 35
sequence_length_ = 20  # length of sequence for each agent distraction
engine_id3 = test_df[test_df['id'] == 3]
engine_id3_50cycleWindow = engine_id3[engine_id3['RUL'] <= engine_id3['RUL'].min() + 50]
cols1 = ['s2', 's3', 's4', 's7', 's8', 's9', 's11']
engine_id3_50cycleWindow1 = engine_id3_50cycleWindow[cols1]
cols2 = ['s12', 's13', 's14', 's15', 's17', 's20', 's21']
engine_id3_50cycleWindow2 = engine_id3_50cycleWindow[cols2]

# plotting sensor data for engine ID 3 prior to a failure point - sensors 2, 3, 4, 7, 8, 9, 11
ax1 = engine_id3_50cycleWindow1.plot(subplots=True, sharex=True, figsize=(20,20))

# plotting sensor data for engine ID 3 prior to a failure point - sensors 12, 13, 14, 15, 17, 20, 21
ax2 = engine_id3_50cycleWindow2.plot(subplots=True, sharex=True, figsize=(20,20))

# %% [markdown]
# ## Generate Train Data

# %%
# pick the feature columns
sensor_cols = ['s2', 's3', 's4', 's7', 's8', 's9', 's11', 's12', 's13', 's14', 's15', 's17', 's20', 's21']
sequence_cols = ['setting1', 'setting2', 'cycle_norm']
sequence_cols.extend(sensor_cols)

# %% [markdown]
# ### generator train data for the sequences for each agent and save in a list

# %%
# Train data
# generator train data for the sequences for each agent and save in a list
data_array_ = {}
for i in train_df['id'].unique():
    seq_gen_ = (list(gen_sequence(train_df[train_df['id'] == id], sequence_length_, sequence_cols)) for id in [i])
    data_array_[i] = np.concatenate(list(seq_gen_)).astype(np.float32)

# %% [markdown]
# ### generate train labels for each agent and save in a list

# %%
label_array_ = {}
# generate train labels for each agent and save in a list
for i in train_df['id'].unique():
    label_gen_ = (gen_labels(train_df[train_df['id'] == id], sequence_length_, ['label1']) for id in [i])
    label_array_[i] = np.concatenate(list(label_gen_)).astype(np.float32)

# %% [markdown]
# ### Generate train labels based on RUL for each agent and save in a list

# %%
label_array_rul_ = {}
# Generate train labels based on RUL for each agent and save in a list
for i in train_df['id'].unique():
    label_gen_rul_ = (gen_labels(train_df[train_df['id'] == id], sequence_length_, ['RUL']) for id in [i])
    label_array_rul_[i] = np.concatenate(list(label_gen_rul_)).astype(np.int)
# Out:
# C:\Users\alibei\AppData\Local\Temp/ipykernel_10504/1920039281.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   label_array_rul_[i] = np.concatenate(list(label_gen_rul_)).astype(np.int)

# %%
# Find the minimum length of dataset for each agent
min_length = label_array_rul_[1].shape[0]
for i in train_df['id'].unique():
    if min_length > label_array_rul_[i].shape[0]:
        min_length = label_array_rul_[i].shape[0]

# %%
# set all length of lists to the minimum length of arrays
for i in train_df['id'].unique():
    label_array_rul_[i] = label_array_rul_[i][len(label_array_rul_[i]) - min_length:, :]
    label_array_[i] = label_array_[i][len(label_array_[i]) - min_length:, :]
    data_array_[i] = data_array_[i][len(data_array_[i]) - min_length:, :, :]
    
print(len(data_array_))
print(len(label_array_))
print(len(label_array_rul_))

print(data_array_[1].shape)
print(label_array_[1].shape)
print(label_array_rul_[1].shape)
# Out:
# 100
# 100
# 100
# (125, 20, 17)
# (125, 1)
# (125, 1)

# %% [markdown]
# ### generator test data for the sequences for each agent and save in a list

# %%
# Test Data
# generator test data for the sequences for each agent and save in a list
seq_array_test_ = {}
for i in test_df['id'].unique():
    seq_gen_test_ = (list(gen_sequence(test_df[test_df['id'] == id], sequence_length_, sequence_cols)) for id in
                     [i])
    seq_array_test_[i] = np.concatenate(list(seq_gen_test_)).astype(np.float32)

# %% [markdown]
# ### generate test labels for each agent and save in a list

# %%
label_array_test_ = {}
# generatAe test labels for each agent and save in a list
for i in test_df['id'].unique():
    label_gen_test_ = (gen_labels(test_df[test_df['id'] == id], sequence_length_, ['label1']) for id in [i])
    label_array_test_[i] = np.concatenate(list(label_gen_test_)).astype(np.float32)

# %% [markdown]
# ### Generate test labels based on RUL for each agent and save in a list

# %%
label_array_test_rul_ = {}
# Generate test labels based on RUL for each agent and save in a list
for i in test_df['id'].unique():
    label_gen_test_rul_ = (gen_labels(test_df[test_df['id'] == id], sequence_length_, ['RUL']) for id in [i])
    label_array_test_rul_[i] = np.concatenate(list(label_gen_test_rul_)).astype(np.int)
# Out:
# C:\Users\alibei\AppData\Local\Temp/ipykernel_10504/500274830.py:5: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   label_array_test_rul_[i] = np.concatenate(list(label_gen_test_rul_)).astype(np.int)

# %% [markdown]
# ### Select part of the train set which has the length longer than min_length

# %%
seq_array_test_tmp = {}
label_array_test_tmp = {}
label_array_test_rul_tmp = {}
for i in test_df['id'].unique():
    tmp = seq_array_test_[i].shape[0]
    if tmp >= min_length:
        seq_array_test_tmp[i] = seq_array_test_[i]
        label_array_test_tmp[i] = label_array_test_[i]
        label_array_test_rul_tmp[i] = label_array_test_rul_[i]

# %% [markdown]
# ###  change the key of dictionary and indexing it based on increasing number from 1

# %%
# change the key of dictionary and indexing it based on increasing number from 1
seq_array_test_ = {}
label_array_test_ = {}
label_array_test_rul_ = {}
j = 1
for i in seq_array_test_tmp.keys():
    seq_array_test_[j] = seq_array_test_tmp[i]
    label_array_test_[j] = label_array_test_tmp[i]
    label_array_test_rul_[j] = label_array_test_rul_tmp[i]
    j += 1

del seq_array_test_tmp
del label_array_test_tmp
del label_array_test_rul_tmp

# set all length of test lists to the minimum length of arrays (min_length)
for i in seq_array_test_.keys():
    label_array_test_rul_[i] = label_array_test_rul_[i][len(label_array_test_rul_[i]) - min_length:, :]
    label_array_test_[i] = label_array_test_[i][len(label_array_test_[i]) - min_length:, :]
    seq_array_test_[i] = seq_array_test_[i][len(seq_array_test_[i]) - min_length:, :, :]

print(len(seq_array_test_))
print(len(label_array_test_))
print(len(label_array_test_rul_))

print(seq_array_test_[1].shape)
print(label_array_test_[1].shape)
print(label_array_test_rul_[1].shape)

X = {}
Y = {}
for i in data_array_.keys():
    X[i - 1] = data_array_[i].reshape(min_length, -1)
    Y[i - 1] = label_array_rul_[i]

X_test = {}
Y_test = {}
for i in seq_array_test_.keys():
    X_test[i - 1] = seq_array_test_[i].reshape(min_length, -1)
    Y_test[i - 1] = label_array_test_rul_[i]
# Out:
# 53
# 53
# 53
# (125, 20, 17)
# (125, 1)
# (125, 1)

# %% [markdown]
# ## The main distributed LSTM model for 10 worker, in case of master and workers

# %%
num_workers = 10
array_params = [dict() for i in range(num_workers)]
J = [list() for i in range(num_workers)]

worker_model = {}
for worker_i in range(num_workers):
    worker_model[worker_i] = LSTM()
    array_params[worker_i] = worker_model[worker_i].init_random_params()

iteration_epoch = 3000
for i in range(iteration_epoch):
    print("Number of iteration:", i, "/from", iteration_epoch)
    for worker_i in range(num_workers):
        cost, array_params[worker_i] = worker_model[worker_i].train(X[worker_i], Y[worker_i],
                                                                    array_params[worker_i])
        J[worker_i].append(cost)

    for key in array_params[0]:  # Fed average
        tmp = array_params[0][key]
        for worker_i in range(1, num_workers):
            tmp = tmp + array_params[worker_i][key]
        for worker_i in range(num_workers):
            array_params[worker_i][key] = (1 / num_workers) * tmp  # Distribute aggregate parameters to all workers
# Out:
# Number of iteration: 0 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [115.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.43]
# Number of iteration: 1 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [115.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.41]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.41]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.41]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.44]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.43]
# Number of iteration: 2 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [115.39]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.4]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.39]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.39]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.41]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.4]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.4]
# Number of iteration: 3 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [115.35]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.36]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.34]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.34]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.34]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.35]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.34]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.37]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.36]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.36]
# Number of iteration: 4 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [115.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.31]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.29]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.29]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.32]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.31]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.31]
# Number of iteration: 5 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [115.24]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.25]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.24]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.24]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.25]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.25]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.24]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.26]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.26]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.25]
# Number of iteration: 6 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [115.18]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.2]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.18]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.18]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.19]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.19]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.18]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.21]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.21]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.2]
# Number of iteration: 7 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [115.13]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.14]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.12]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.12]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.14]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.13]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.12]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.16]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.15]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.14]
# Number of iteration: 8 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [115.07]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.08]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.06]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.07]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.09]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.08]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.06]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.1]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.1]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.08]
# Number of iteration: 9 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [115.01]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.03]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.01]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.02]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.04]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.02]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.05]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.05]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.03]
# Number of iteration: 10 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.97]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.97]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.98]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.97]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.]
# Epoch 0 	Batch: 75 - 100 	Loss: [115.]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.98]
# Number of iteration: 11 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.91]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.92]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.92]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.93]
# Number of iteration: 12 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.84]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.86]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.84]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.87]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.87]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.87]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.91]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.87]
# Number of iteration: 13 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.8]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.79]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.8]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.86]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.83]
# Number of iteration: 14 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.75]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.77]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.77]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.75]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.81]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.78]
# Number of iteration: 15 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.67]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.71]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.68]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.72]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.71]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.76]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.77]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.73]
# Number of iteration: 16 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.62]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.66]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.63]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.67]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.68]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.66]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.72]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.68]
# Number of iteration: 17 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.57]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.61]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.65]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.61]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.63]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.61]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.67]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.63]
# Number of iteration: 18 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.52]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.53]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.61]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.57]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.59]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.63]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.65]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.58]
# Number of iteration: 19 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.52]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.57]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.52]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.55]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.52]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.61]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.53]
# Number of iteration: 20 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.44]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.52]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.5]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.48]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.57]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.49]
# Number of iteration: 21 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.36]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.4]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.46]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.53]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.44]
# Number of iteration: 22 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.32]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.35]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.45]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.4]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.44]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.48]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.4]
# Number of iteration: 23 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.27]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.33]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.31]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.41]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.34]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.35]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.4]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.44]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.35]
# Number of iteration: 24 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.22]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.26]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.37]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.29]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.33]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.31]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.36]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.4]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.31]
# Number of iteration: 25 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.18]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.23]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.22]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.33]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.25]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.29]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.27]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.31]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.36]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.26]
# Number of iteration: 26 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.13]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.19]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.17]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.21]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.24]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.23]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.27]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.32]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.22]
# Number of iteration: 27 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.09]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.14]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.13]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.25]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.16]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.2]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.19]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.22]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.17]
# Number of iteration: 28 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [114.04]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.09]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.08]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.21]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.12]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.16]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.15]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.18]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.24]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.12]
# Number of iteration: 29 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.99]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.04]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.03]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.17]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.08]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.12]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.11]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.14]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.2]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.08]
# Number of iteration: 30 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.99]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.98]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.13]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.03]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.08]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.06]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.09]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.16]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.03]
# Number of iteration: 31 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.88]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.09]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.99]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.03]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.02]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.05]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.12]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.98]
# Number of iteration: 32 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.83]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.89]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.89]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.06]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.99]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.97]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.01]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.08]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.94]
# Number of iteration: 33 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.84]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.83]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.01]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.96]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.04]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.89]
# Number of iteration: 34 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.97]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.88]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.91]
# Epoch 0 	Batch: 75 - 100 	Loss: [114.]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.84]
# Number of iteration: 35 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.8]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.84]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.86]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.96]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.79]
# Number of iteration: 36 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.63]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.68]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.68]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.75]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.81]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.79]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.92]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.75]
# Number of iteration: 37 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.62]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.63]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.86]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.76]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.74]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.88]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.7]
# Number of iteration: 38 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.53]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.64]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.72]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.74]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.84]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.65]
# Number of iteration: 39 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.48]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.53]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.79]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.59]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.67]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.65]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.7]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.8]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.6]
# Number of iteration: 40 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.48]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.75]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.63]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.59]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.66]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.76]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.54]
# Number of iteration: 41 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.39]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.44]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.72]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.55]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.61]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.72]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.49]
# Number of iteration: 42 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.34]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.37]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.68]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.53]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.5]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.67]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.44]
# Number of iteration: 43 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.33]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.31]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.64]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.48]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.46]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.53]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.63]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.38]
# Number of iteration: 44 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.23]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.27]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.26]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.6]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.32]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.41]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.33]
# Number of iteration: 45 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.17]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.22]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.2]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.57]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.27]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.35]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.44]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.27]
# Number of iteration: 46 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.13]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.16]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.14]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.53]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.22]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.33]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.4]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.22]
# Number of iteration: 47 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.08]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.11]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.09]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.16]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.25]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.36]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.44]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.16]
# Number of iteration: 48 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [113.02]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.05]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.03]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.45]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.1]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.24]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.2]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.32]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.39]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.12]
# Number of iteration: 49 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.96]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.02]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.97]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.04]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.18]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.15]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.36]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.06]
# Number of iteration: 50 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.96]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.91]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.98]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.13]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.09]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.23]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.31]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.]
# Number of iteration: 51 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.84]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.34]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.08]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.04]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.18]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.26]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.96]
# Number of iteration: 52 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.84]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.79]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.89]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.03]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.13]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.21]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.9]
# Number of iteration: 53 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.72]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.27]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.83]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.99]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.1]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.15]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.84]
# Number of iteration: 54 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.68]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.71]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.67]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.23]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.77]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.88]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.05]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.12]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.77]
# Number of iteration: 55 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.62]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.65]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.6]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.18]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.71]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.88]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.81]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.01]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.06]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.71]
# Number of iteration: 56 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.6]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.14]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.66]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.83]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.75]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.96]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.01]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.65]
# Number of iteration: 57 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.5]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.53]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.48]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.1]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.6]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.79]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.59]
# Number of iteration: 58 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.06]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.55]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.75]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.63]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.91]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.52]
# Number of iteration: 59 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.37]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.4]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.36]
# Epoch 0 	Batch: 75 - 100 	Loss: [113.02]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.46]
# Number of iteration: 60 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.31]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.34]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.29]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.98]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.65]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.5]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.76]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.8]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.4]
# Number of iteration: 61 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.24]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.23]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.37]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.59]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.74]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.34]
# Number of iteration: 62 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.17]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.22]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.16]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.89]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.52]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.36]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.68]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.27]
# Number of iteration: 63 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.11]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.16]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.1]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.24]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.46]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.64]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.62]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.21]
# Number of iteration: 64 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [112.05]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.09]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.03]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.81]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.17]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.39]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.24]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.59]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.15]
# Number of iteration: 65 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.98]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.02]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.96]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.77]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.11]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.33]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.18]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.52]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.52]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.09]
# Number of iteration: 66 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.91]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.96]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.89]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.72]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.04]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.26]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.11]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.46]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.45]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.02]
# Number of iteration: 67 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.89]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.83]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.68]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.97]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.2]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.04]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.96]
# Number of iteration: 68 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.76]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.64]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.91]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.13]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.98]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.37]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.32]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.89]
# Number of iteration: 69 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.72]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.76]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.59]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.07]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.92]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.31]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.26]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.83]
# Number of iteration: 70 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.66]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.62]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.55]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.79]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.03]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.87]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.26]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.23]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.77]
# Number of iteration: 71 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.59]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.62]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.51]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.97]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.8]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.21]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.17]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.71]
# Number of iteration: 72 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.53]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.66]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.74]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.16]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.1]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.64]
# Number of iteration: 73 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.51]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.6]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.84]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.68]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.1]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.06]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.58]
# Number of iteration: 74 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.41]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.44]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.36]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.79]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.62]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.07]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.52]
# Number of iteration: 75 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.35]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.33]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.02]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.46]
# Number of iteration: 76 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.32]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.23]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.41]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.5]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.97]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.4]
# Number of iteration: 77 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.22]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.26]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.17]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.25]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.35]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.65]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.44]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.87]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.33]
# Number of iteration: 78 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.15]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.19]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.1]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.2]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.59]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.37]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.87]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.8]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.27]
# Number of iteration: 79 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.09]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.13]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.04]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.15]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.22]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.52]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.83]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.74]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.2]
# Number of iteration: 80 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [111.02]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.06]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.97]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.1]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.15]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.46]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.24]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.77]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.67]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.13]
# Number of iteration: 81 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [110.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.05]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.09]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.39]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.17]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.7]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.6]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.07]
# Number of iteration: 82 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [110.88]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.83]
# Epoch 0 	Batch: 75 - 100 	Loss: [112.]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.02]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.34]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.11]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.64]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.55]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.]
# Number of iteration: 83 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [110.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.87]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.76]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.27]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.04]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.48]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.93]
# Number of iteration: 84 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [110.75]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.81]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.7]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.89]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.89]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.2]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.98]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.51]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.41]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.87]
# Number of iteration: 85 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [110.68]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.74]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.63]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.83]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.14]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.91]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.44]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.35]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.8]
# Number of iteration: 86 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [110.61]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.67]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.79]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.75]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.07]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.84]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.29]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.73]
# Number of iteration: 87 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [110.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.61]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.74]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.68]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.77]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.31]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.22]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.66]
# Number of iteration: 88 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [110.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.61]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.7]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.25]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.15]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.59]
# Number of iteration: 89 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [110.4]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.35]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.63]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.86]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.63]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.18]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.09]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.52]
# Number of iteration: 90 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [110.33]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.4]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.8]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.13]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.02]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.46]
# Number of iteration: 91 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [110.26]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.34]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.21]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.52]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.4]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.06]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.96]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.39]
# Number of iteration: 92 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [110.19]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.27]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.14]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.46]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.33]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.66]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.99]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.89]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.32]
# Number of iteration: 93 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [110.12]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.21]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.06]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.41]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.26]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.59]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.35]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.83]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.26]
# Number of iteration: 94 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [110.06]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.14]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.99]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.34]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.19]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.86]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.76]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.19]
# Number of iteration: 95 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [109.99]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.08]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.92]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.11]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.21]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.8]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.12]
# Number of iteration: 96 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [109.92]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.02]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.21]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.04]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.41]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.14]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.74]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.62]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.05]
# Number of iteration: 97 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [109.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.16]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.98]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.34]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.06]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.67]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.99]
# Number of iteration: 98 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [109.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.88]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.71]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.1]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.91]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.99]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.61]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.92]
# Number of iteration: 99 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [109.71]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.64]
# Epoch 0 	Batch: 75 - 100 	Loss: [111.05]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.84]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.21]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.92]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.86]
# Number of iteration: 100 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [109.64]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.75]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.57]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.98]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.77]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.16]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.48]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.35]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.79]
# Number of iteration: 101 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [109.57]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.5]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.7]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.09]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.79]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.72]
# Number of iteration: 102 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [109.5]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.63]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.86]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.63]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.03]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.37]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.21]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.65]
# Number of iteration: 103 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [109.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.36]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.81]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.96]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.66]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.15]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.58]
# Number of iteration: 104 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [109.36]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.29]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.75]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.5]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.59]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.24]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.08]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.52]
# Number of iteration: 105 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [109.29]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.22]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.7]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.83]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.52]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.17]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.01]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.45]
# Number of iteration: 106 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [109.22]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.37]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.14]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.64]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.36]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.46]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.11]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.38]
# Number of iteration: 107 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [109.15]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.07]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.29]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.71]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.39]
# Epoch 0 	Batch: 75 - 100 	Loss: [110.05]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.87]
# Epoch 0 	Batch: 75 - 100 	Loss: [109.31]
# Number of iteration: 108 /from 3000
# ...
# Epoch 0 	Batch: 75 - 100 	Loss: [62.17]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.48]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.72]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.41]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.75]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.77]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.5]
# Number of iteration: 2964 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.98]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.2]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.2]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.14]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.45]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.7]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.41]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.72]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.75]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.49]
# Number of iteration: 2965 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.97]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.19]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.23]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.13]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.46]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.44]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.71]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.86]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.45]
# Number of iteration: 2966 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.16]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.2]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.12]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.7]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.48]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.47]
# Number of iteration: 2967 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.24]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.27]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.12]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.71]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.48]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.76]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.81]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.42]
# Number of iteration: 2968 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.23]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.24]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.13]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.55]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.71]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.8]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.49]
# Number of iteration: 2969 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.98]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.32]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.7]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.81]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.84]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.46]
# Number of iteration: 2970 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.98]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.31]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.7]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.84]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.46]
# Number of iteration: 2971 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [60.]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.37]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.29]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.67]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.53]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.8]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.45]
# Number of iteration: 2972 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [60.]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.32]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.44]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.86]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.8]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.42]
# Number of iteration: 2973 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.96]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.71]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.8]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.43]
# Number of iteration: 2974 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.98]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.4]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.68]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.83]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.91]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.77]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.42]
# Number of iteration: 2975 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [60.01]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.32]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.32]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.7]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.84]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.57]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.92]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.86]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.39]
# Number of iteration: 2976 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.99]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.46]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.3]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.68]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.86]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.4]
# Number of iteration: 2977 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.96]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.27]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.45]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.28]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.65]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.8]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.89]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.41]
# Number of iteration: 2978 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.29]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.27]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.66]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.79]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.87]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.89]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.38]
# Number of iteration: 2979 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.27]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.48]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.25]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.64]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.77]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.61]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.84]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.96]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.37]
# Number of iteration: 2980 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.23]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.46]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.22]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.61]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.74]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.6]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.81]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.36]
# Number of iteration: 2981 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.96]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.22]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.2]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.63]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.72]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.33]
# Number of iteration: 2982 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.19]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.45]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.17]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.64]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.7]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.75]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.32]
# Number of iteration: 2983 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.97]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.17]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.13]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.63]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.68]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.73]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.91]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.33]
# Number of iteration: 2984 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [60.]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.18]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.48]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.12]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.65]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.66]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.71]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.3]
# Number of iteration: 2985 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.98]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.15]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.46]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.1]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.64]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.64]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.57]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.3]
# Number of iteration: 2986 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.11]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.42]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.07]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.61]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.62]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.59]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.67]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.92]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.34]
# Number of iteration: 2987 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.15]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.07]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.71]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.6]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.6]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.65]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.31]
# Number of iteration: 2988 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.12]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.46]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.03]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.68]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.59]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.61]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.3]
# Number of iteration: 2989 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.89]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.08]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.43]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.65]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.57]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.59]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.6]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.88]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.32]
# Number of iteration: 2990 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.88]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.05]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.41]
# Epoch 0 	Batch: 75 - 100 	Loss: [61.98]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.66]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.54]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.58]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.57]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.87]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.29]
# Number of iteration: 2991 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.86]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.01]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.38]
# Epoch 0 	Batch: 75 - 100 	Loss: [61.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.62]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.52]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.57]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.53]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.28]
# Number of iteration: 2992 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.88]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.97]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.34]
# Epoch 0 	Batch: 75 - 100 	Loss: [61.93]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.59]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.5]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.83]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.27]
# Number of iteration: 2993 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.89]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.95]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.32]
# Epoch 0 	Batch: 75 - 100 	Loss: [61.92]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.55]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.47]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.83]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.25]
# Number of iteration: 2994 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.85]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.29]
# Epoch 0 	Batch: 75 - 100 	Loss: [61.89]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.56]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.46]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.65]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.44]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.82]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.34]
# Number of iteration: 2995 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.14]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.53]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.23]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.87]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.64]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.72]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [73.02]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.32]
# Number of iteration: 2996 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.96]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.15]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.49]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.25]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.9]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.69]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.81]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.72]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.99]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.43]
# Number of iteration: 2997 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [60.]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.37]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.66]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.33]
# Epoch 0 	Batch: 75 - 100 	Loss: [60.02]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.76]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.88]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.77]
# Epoch 0 	Batch: 75 - 100 	Loss: [73.01]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.4]
# Number of iteration: 2998 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [60.01]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.46]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.81]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.34]
# Epoch 0 	Batch: 75 - 100 	Loss: [60.08]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.77]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.91]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.99]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.38]
# Number of iteration: 2999 /from 3000
# Epoch 0 	Batch: 75 - 100 	Loss: [59.99]
# Epoch 0 	Batch: 75 - 100 	Loss: [63.46]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.78]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.34]
# Epoch 0 	Batch: 75 - 100 	Loss: [60.06]
# Epoch 0 	Batch: 75 - 100 	Loss: [59.79]
# Epoch 0 	Batch: 75 - 100 	Loss: [66.94]
# Epoch 0 	Batch: 75 - 100 	Loss: [62.79]
# Epoch 0 	Batch: 75 - 100 	Loss: [72.97]
# Epoch 0 	Batch: 75 - 100 	Loss: [64.48]

# %% [markdown]
# ### Save Cost functions and Parameters

# %%
# Save Cost
dir_logdata_FD003_epoch_1: str = "H:\.1-Electrical_WorkSpace/Projects/Federated Learning on URL Estimation/Machin Learning/DML_Turbofan/Python/Notebook/Results/FedLSTM/FD003/LogData/epoch_1/ "    
num_workers = 10

# Save Cost in PKL file
a_file = open(dir_logdata_FD003_epoch_1 + "J_10Workers_Final_Cost_FedLSTM_itter_3000_alpha_004_epoch_01.pkl", "wb")
pickle.dump(J, a_file)
a_file.close()

# Save parameters
# Save array_params in PKL file
a_file = open(dir_logdata_FD003_epoch_1 + "array_params_10Workers_Final_Cost_FedLSTM_itter_3000_alpha_004_epoch_01.pkl", "wb")
pickle.dump(array_params, a_file)
a_file.close()

# %% [markdown]
# # plot
# ## plot different cost function

# %%
num_workers = 10
iteration_epoch = 3000
epoch = 1
fig, ax = plt.subplots()
fig.set_size_inches(9, 5)
cost_each_worker = np.zeros(shape=(num_workers, 5 * epoch *iteration_epoch))
for worker_i in range(num_workers):
    cost_each_worker[worker_i, :] = np.array(J[worker_i]).flatten()
    plt.plot(cost_each_worker[worker_i, :], label="Edge num " + str(worker_i+1))
plt.title("FedLSTM with FD003 and epoch 1", fontsize="x-large")
plt.ylabel("Cross Entropy loss function", fontsize="x-large")
plt.xlabel("iteration", fontsize="x-large")
plt.grid()
legened = plt.legend(shadow=True, fontsize='large')

dir_logdata_FD003_epoch_1: str = "H:\.1-Electrical_WorkSpace/Projects/Federated Learning on URL Estimation/Machin Learning/DML_Turbofan/Python/Notebook/Results/FedLSTM/FD003/Results/epoch_1/"    
plt.rcParams["savefig.directory"] = os.chdir(os.path.dirname(dir_logdata_FD003_epoch_1))
plt.savefig('J_FD003_Final_Cost_FedLSTM_itter_3000_alpha_004_epoch_01.eps', format='eps', dpi=1200, bbox_inches='tight')
plt.savefig('J_FD003_Final_Cost_FedLSTM_itter_3000_alpha_004_epoch_01.png', format='png', dpi=1200, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Plot test models

# %%
worker_test = LSTM()
fig={}
ax={}
for i in range(len(X_test)):
    Y_hat = worker_test.test_pred(X_test[i], array_params[0])
    fig[i], ax[i] = plt.subplots()
    ax[i].plot(Y_hat, label='Pred RUL', color='#F97306')
    ax[i].plot(Y_test[worker_i], label='True RUL', color='#008000')
    plt.title("Random test engine unit#" + str(i) + " from FD003", fontsize="x-large")
    plt.ylabel("RUL", fontsize="x-large")
    plt.ylim(0, 120)
    plt.xlabel("num of Sequence", fontsize="x-large")
    ax[i].grid()
    ax[i].legend(shadow=True, fontsize='large')
    #plt.rcParams["savefig.directory"] = os.chdir(os.path.dirname(dir_name_epoch_4))
    #plt.savefig("RUL_10Workers_Final_Cost_itter_3000_alpha_004_epoch_04"+str(worker_i)+".eps", format='eps', dpi=1200)
    #plt.savefig("RUL_10Workers_Final_Cost_itter_3000_alpha_004_epoch_04"+str(worker_i)+".png", format='png', dpi=1200)
# Out:
# C:\Users\alibei\AppData\Local\Temp/ipykernel_10504/1608696564.py:6: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig[i], ax[i] = plt.subplots()

# %%
# Save Specific figures
dir_name: str = "H:\.1-Electrical_WorkSpace/Projects/Federated Learning on URL Estimation/Machin Learning/DML_Turbofan/Python/Notebook/Results/FedLSTM/FD003/Results/epoch_1/"    
plt.rcParams["savefig.directory"] = os.chdir(os.path.dirname(dir_name))
fig[23].savefig("FD003 RUL prediction with FedLSTM and epoch 1 for machine number_" + str(23) + ".eps", format='eps', dpi=1200, bbox_inches='tight')
fig[23].savefig("FD003 RUL prediction with FedLSTM and epoch 1 for machine number_" + str(23) + ".png", format='png', dpi=1200, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### RMSE and SCORE

# %%
# RMSE and Scoring factor epoch 1
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())


RMSE = np.zeros(shape=(len(X_test),1))


for worker_i in range(len(X_test)):
    Y_hat = worker_test.test_pred(X_test[worker_i], array_params[0])
    RMSE[worker_i] = rmse(Y_hat, Y_test[worker_i])

fig, ax = plt.subplots()
plt.plot(RMSE, label='RMSE', marker = 's')
plt.title("RMSE for RUL estimation on FD003 epoch 1", fontsize="x-large")
plt.ylabel("RMSE", fontsize="x-large")
plt.xlabel("Bach of test data", fontsize="x-large")
plt.grid()


labels = []
labels.append("total RMSE ="+str(RMSE_epoch_1))

plt.legend(labels, loc='best', fontsize='large')

RMSE_epoch_1 = np.sum(RMSE, axis=0)/len(X_test)
print(RMSE_epoch_1)
plt.rcParams["savefig.directory"] = os.chdir(os.path.dirname(dir_name))
plt.savefig("RMSE for RUL estimation FedLSTM on test dataset FD003 epoch 1.eps", format='eps', dpi=1200, bbox_inches='tight')
plt.savefig("RMSE for RUL estimation FedLSTM on test dataset FD003 epoch 1.png", format='png', dpi=1200, bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# [17.95875139]

# %%
def each_score(predictions, targets):
    tmp = np.zeros(shape=(1, len(predictions)))
    for i in range(len(predictions)):
        Yi = predictions[i] - targets[i]
        if Yi >= 0:
            tmp[:, i] = (np.exp(Yi/10)-1)   
        else:
            tmp[:, i] = np.exp(Yi/13)-1
    return tmp
    
SCORE = np.zeros(shape=(len(X_test), X_test[0].shape[0]))

for worker_i in range(len(X_test)):
    Y_hat = worker_test.test_pred(X_test[worker_i], array_params[0])
    SCORE[worker_i, :] = each_score(Y_hat, Y_test[worker_i])
    
print(np.sum(SCORE, axis=1))
plt.plot(np.sum(SCORE, axis=1))
print("Final value for SCORE:",np.sum(SCORE)/len(X_test))
# Out:
# [-7.27166208e+01  3.02546778e+03 -6.26344591e+01 -6.32387583e+01
#  -6.42115463e+01 -6.02382408e+01 -3.70996995e+01 -7.35185723e+01
#  -4.91001616e+01 -5.00218466e+01  3.69532194e+00 -9.35339611e+01
#   5.10135279e+01 -6.02623741e+01 -8.93867070e+01 -6.13392600e+01
#  -6.94645126e+01 -4.34768399e+01 -7.45742529e+01 -5.65438572e+01
#   2.58723772e+03 -4.13091398e+01 -6.43758777e+01  1.81340552e+02
#  -6.44111229e+01 -5.90559954e+01 -6.56937688e+01 -5.45334102e+01
#  -4.32842943e+01 -5.10265902e+01 -6.98918834e+01 -5.43538615e+01
#  -2.54611202e+01 -5.68293492e+01 -2.41089408e+00  1.58900248e+02
#  -9.59911761e+01 -3.91623464e+01  6.74959781e+01  3.46946765e+03
#   7.78414108e+02 -6.90446910e+01  3.61391854e+01 -7.76195815e+01
#  -6.64104860e+01 -2.08286941e+01 -8.93672416e+00  1.15349300e+02
#  -6.90128609e+01 -6.25463149e+01  8.25031269e+01  5.87921955e+00
#  -2.08686617e+01]
# Final value for SCORE: 156.5751548380605

# %% [markdown]
# ## Load Cost functions and Parameters

# %%
import numpy as np
import pickle
# from model import *

# Import libraries
from random import uniform
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

import time
import math
import sys
import random
# Load cost from a PKL file
a_file = open("J_10Workers_Final_Cost_itter_3000_alpha_004_epoch_01.pkl", "rb")
J = pickle.load(a_file)
a_file.close()

# Load params data from a PKL file
a_file = open("array_params_10Workers_Final_Cost_itter_3000_alpha_004_epoch_01.pkl", "rb")
array_params = pickle.load(a_file)
print(array_params)
a_file.close()
# Out:
# [{'Wf': array([[-0.18564977,  0.0322141 , -0.04818845, ..., -0.12048841,
#          0.09804777,  0.05325   ],
#        [-0.06109197,  0.09811411, -0.04168961, ...,  0.08114126,
#          0.08047905,  0.05512676],
#        [-0.12158022, -0.13627538, -0.17668155, ..., -0.20193493,
#          0.20272957,  0.12999881],
#        ...,
#        [ 0.01255876,  0.16984161,  0.03624951, ..., -0.08108413,
#          0.04121908,  0.00478767],
#        [ 0.02036318,  0.06390896, -0.02934949, ...,  0.06846599,
#          0.09238949,  0.08252651],
#        [ 0.04791726,  0.01360442, -0.01159031, ...,  0.07645322,
#          0.05202115,  0.05020851]]), 'bf': array([[1.05032015],
#        [1.08373612],
#        [1.08920687],
#        [1.02828693],
#        [1.0825476 ],
#        [1.14573225],
#        [1.04020056],
#        [1.06803859],
#        [1.07327751],
#        [1.0113719 ],
#        [1.0307025 ],
#        [1.02641318],
#        [1.07471422],
#        [1.07047969],
#        [1.10095669],
#        [1.0111647 ],
#        [1.06367949],
#        [1.00765221],
#        [1.06906137],
#        [0.96677803],
#        [1.08039571],
#        [1.03641633],
#        [1.05174676],
#        [1.05926491],
#        [1.03266059],
#        [1.03454594],
#        [1.04518686],
#        [1.02190527],
#        [0.99047914],
#        [1.06126317],
#        [1.0231569 ],
#        [0.96593006],
#        [1.04133929],
#        [1.05839786],
#        [1.05678469],
#        [1.0367519 ],
#        [1.0780693 ],
#        [1.03939944],
#        [1.02982651],
#        [1.22984627],
#        [1.03927436],
#        [1.07138223],
#        [0.95980763],
#        [1.0829577 ],
#        [1.04272909],
#        [1.06227023],
#        [1.06841976],
#        [1.06722668],
#        [1.05371202],
#        [1.03970251],
#        [0.98573322],
#        [1.04839654],
#        [1.05071212],
#        [1.0469534 ],
#        [1.06516054],
#        [1.0706018 ],
#        [1.05523076],
#        [1.12127272],
#        [1.06043332],
#        [1.07008934],
#        [1.09667145],
#        [1.06153483],
#        [1.06684203],
#        [1.04942246],
#        [0.98643897],
#        [1.0601797 ],
#        [1.09068705],
#        [1.08716404],
#        [1.07461371],
#        [1.05921925],
#        [1.1096217 ],
#        [1.05080112],
#        [1.06219055],
#        [1.04544236],
#        [1.02574146],
#        [1.04223387],
#        [1.0789061 ],
#        [1.06871694],
#        [1.00216853],
#        [1.03048419],
#        [1.09819103],
#        [1.0339168 ],
#        [1.06167599],
#        [1.07701336],
#        [1.15397874],
#        [1.03744954],
#        [1.04158555],
#        [1.03149759],
#        [1.06037439],
#        [1.19617647],
#        [1.07607425],
#        [1.04414393],
#        [1.06219875],
#        [1.04168023],
#        [1.03966008],
#        [1.05335521],
#        [1.05828675],
#        [1.08734352],
#        [1.0850512 ],
#        [1.07113528]]), 'Wi': array([[-0.35876051,  0.06531404, -0.0810624 , ...,  0.00274041,
#          0.05487662,  0.05608973],
#        [-0.02115981,  0.16963216,  0.01860463, ..., -0.05882116,
#         -0.06700962, -0.05634284],
#        [-0.05834764,  0.09453896, -0.52647594, ..., -0.03518341,
#          0.02156149, -0.00295659],
#        ...,
#        [ 0.04369218,  0.13116003, -0.00631491, ...,  0.00607538,
#          0.0172913 ,  0.00894547],
#        [-0.03737363,  0.04248013, -0.05293714, ..., -0.01780473,
#          0.00229196,  0.01785574],
#        [ 0.19273605,  0.04437742, -0.06902674, ...,  0.10098549,
#          0.07390661,  0.08306758]]), 'bi': array([[1.06310218],
#        [0.92990866],
#        [1.00094982],
#        [1.01148314],
#        [0.91543413],
#        [1.0444907 ],
#        [1.07523039],
#        [1.02228579],
#        [1.02388617],
#        [1.04516746],
#        [1.01485734],
#        [1.05083217],
#        [0.92861285],
#        [0.89280231],
#        [0.90778182],
#        [0.98646694],
#        [0.88533849],
#        [1.08666432],
#        [1.09543124],
#        [1.08280484],
#        [0.93904937],
#        [0.99344404],
#        [1.07994221],
#        [0.98085908],
#        [1.07862968],
#        [1.01444385],
#        [1.01054248],
#        [1.01944683],
#        [0.91403935],
#        [1.09171777],
#        [1.01828847],
#        [0.93559894],
#        [0.86841702],
#        [0.9403288 ],
#        [0.92760146],
#        [0.92544675],
#        [1.08299736],
#        [0.98749211],
#        [1.01798561],
#        [1.03829483],
#        [1.06950872],
#        [1.06630134],
#        [0.96753854],
#        [1.01268341],
#        [0.89676864],
#        [1.01603013],
#        [1.01269679],
#        [1.08165328],
#        [0.99150468],
#        [0.96138165],
#        [1.10431166],
#        [1.01755167],
#        [1.04225208],
#        [1.02529198],
#        [1.02694045],
#        [0.98597997],
#        [1.08226956],
#        [1.12092312],
#        [0.9744185 ],
#        [1.08911062],
#        [0.89821867],
#        [0.9171116 ],
#        [1.03102649],
#        [1.05092667],
#        [1.05004195],
#        [1.00800867],
#        [1.05608546],
#        [0.93148772],
#        [1.01405444],
#        [1.08888074],
#        [1.04437569],
#        [1.03171239],
#        [0.99902858],
#        [0.95864753],
#        [0.95169849],
#        [1.05928478],
#        [1.09368392],
#        [0.9337258 ],
#        [0.91509546],
#        [0.89668974],
#        [0.93814484],
#        [0.99035026],
#        [1.03492126],
#        [1.08117836],
#        [1.01898899],
#        [0.99873661],
#        [1.04786245],
#        [1.05492367],
#        [1.08212118],
#        [1.04204744],
#        [1.03400105],
#        [0.99604101],
#        [1.01853205],
#        [0.94655013],
#        [0.93071023],
#        [0.8735768 ],
#        [1.00628304],
#        [1.02267514],
#        [0.99075036],
#        [1.07400993]]), 'Wc': array([[ 0.37616002,  0.02491891, -0.16121304, ..., -0.01979567,
#          0.03319335, -0.00905801],
#        [-0.05548154,  0.03803616, -0.08985911, ...,  0.00502674,
#          0.03138603, -0.00736547],
#        [-0.04201148, -0.48292646, -0.10278721, ..., -0.09180324,
#          0.06113852,  0.02728158],
#        ...,
#        [-0.11654761, -0.0104881 , -0.15111948, ...,  0.06422703,
#         -0.10138768, -0.08637677],
#        [ 0.09284664, -0.05476818,  0.17276274, ..., -0.01931532,
#         -0.02076231,  0.01510171],
#        [ 0.02327513,  0.01733433,  0.0549094 , ...,  0.05078404,
#          0.06554274,  0.05709571]]), 'bc': array([[1.03589755],
#        [1.01915656],
#        [1.03523764],
#        [1.02248092],
#        [1.02520051],
#        [1.04299373],
#        [0.94975647],
#        [1.02238728],
#        [1.02044663],
#        [1.1655931 ],
#        [0.97585952],
#        [1.05157461],
#        [0.99023144],
#        [0.94506799],
#        [1.04683025],
#        [1.0010047 ],
#        [1.00985231],
#        [0.94177456],
#        [1.03105369],
#        [0.94082989],
#        [1.02116679],
#        [0.95252642],
#        [1.05234621],
#        [0.97390832],
#        [1.05059981],
#        [0.97570774],
#        [1.01742244],
#        [0.94000179],
#        [0.95774629],
#        [0.97091481],
#        [1.01490546],
#        [1.0279857 ],
#        [1.00623192],
#        [0.97624643],
#        [1.01290159],
#        [0.98277848],
#        [0.9844326 ],
#        [1.03506707],
#        [1.01577092],
#        [1.14482741],
#        [0.93288968],
#        [0.98755631],
#        [1.0285273 ],
#        [0.95000179],
#        [0.96627523],
#        [0.97777189],
#        [0.96324735],
#        [1.04001476],
#        [0.99964198],
#        [1.01066716],
#        [0.988613  ],
#        [0.95664921],
#        [0.97504551],
#        [0.96505431],
#        [0.98037449],
#        [0.93898289],
#        [1.04311048],
#        [0.96049968],
#        [1.01575065],
#        [1.05808651],
#        [1.05362685],
#        [1.03389352],
#        [0.93981673],
#        [0.97309158],
#        [1.07521014],
#        [0.94727507],
#        [1.02666901],
#        [1.04417164],
#        [0.95587008],
#        [1.01558597],
#        [1.01345543],
#        [0.95053742],
#        [1.0097536 ],
#        [0.97210992],
#        [0.98224041],
#        [1.04193398],
#        [1.04426981],
#        [1.02272641],
#        [1.01569378],
#        [1.01828445],
#        [1.03590943],
#        [0.96554822],
#        [1.03350835],
#        [1.06092297],
#        [1.0576234 ],
#        [1.03997474],
#        [1.11441306],
#        [1.0260518 ],
#        [1.04732082],
#        [0.95708873],
#        [0.96839852],
#        [0.94005503],
#        [0.97872314],
#        [1.02740615],
#        [0.95679057],
#        [1.01381791],
#        [0.99446321],
#        [0.87571497],
#        [1.0007616 ],
#        [1.05591098]]), 'Wo': array([[-0.07029353,  0.08007363, -0.11357934, ...,  0.07795353,
#          0.10019695,  0.08088321],
#        [ 0.15905675,  0.09932922, -0.10309724, ...,  0.02991522,
#          0.05857103,  0.04865553],
#        [-0.29251172, -0.05999288, -0.27306726, ..., -0.03054881,
#          0.1350382 ,  0.14812509],
#        ...,
#        [ 0.08772661,  0.10673849, -0.00115548, ...,  0.04290671,
#          0.06545332,  0.0763722 ],
#        [ 0.04237087, -0.08847114, -0.13073105, ..., -0.20042277,
#          0.1409413 ,  0.11217493],
#        [-0.00465607, -0.04759776,  0.09463798, ...,  0.07904445,
#         -0.17132684, -0.08295297]]), 'bo': array([[1.08483459],
#        [1.01442682],
#        [1.05505123],
#        [1.06302764],
#        [1.01167186],
#        [1.07951384],
#        [0.94896253],
#        [0.99405769],
#        [0.98760615],
#        [1.08418421],
#        [1.05841547],
#        [1.04842251],
#        [1.00759666],
#        [1.05535328],
#        [1.00678728],
#        [0.99191856],
#        [1.05720347],
#        [1.02658226],
#        [1.01987389],
#        [1.02017922],
#        [1.02790269],
#        [0.91845656],
#        [0.96300877],
#        [1.0788484 ],
#        [0.96535852],
#        [1.07945143],
#        [1.06165371],
#        [1.10206712],
#        [1.04604272],
#        [0.99262183],
#        [1.04192852],
#        [0.94856452],
#        [1.01057044],
#        [1.0526348 ],
#        [1.00750781],
#        [1.03677126],
#        [1.09536193],
#        [1.03911276],
#        [0.99722213],
#        [1.03709059],
#        [1.10294905],
#        [1.08686586],
#        [1.12098127],
#        [0.9799658 ],
#        [1.03306697],
#        [1.08063732],
#        [0.96981011],
#        [0.90780337],
#        [1.0869364 ],
#        [1.03806227],
#        [1.03582956],
#        [0.96907334],
#        [1.07658574],
#        [1.00371491],
#        [1.07048012],
#        [1.0667711 ],
#        [0.98352455],
#        [1.10008805],
#        [1.02106115],
#        [0.94118526],
#        [1.02049945],
#        [1.06117039],
#        [0.99869695],
#        [1.00320191],
#        [1.02055282],
#        [0.99612243],
#        [1.10574692],
#        [0.99426786],
#        [1.02786473],
#        [0.98043052],
#        [1.11625467],
#        [1.02060557],
#        [1.00993411],
#        [1.09183542],
#        [1.05379105],
#        [0.9777543 ],
#        [0.96852636],
#        [1.01553117],
#        [1.03125061],
#        [0.97970334],
#        [0.99001403],
#        [1.08278532],
#        [0.94347595],
#        [0.97013913],
#        [0.99236927],
#        [1.08182622],
#        [1.00267792],
#        [1.05509985],
#        [0.98642501],
#        [1.04115096],
#        [1.00331833],
#        [0.91396723],
#        [1.07651437],
#        [1.07237476],
#        [0.99770155],
#        [1.01506561],
#        [1.11002575],
#        [1.07522041],
#        [1.04765811],
#        [0.95166721]]), 'Wv': array([[-0.2386224 , -0.1976348 ,  1.51062579, ...,  0.15778947,
#          1.06544564, -0.12085933],
#        [-0.24415036, -0.29229287,  1.44721086, ...,  0.19354405,
#          0.89592646, -0.11803306],
#        [-0.24768419, -0.25671892,  1.33293496, ...,  0.18161202,
#          0.84000461, -0.2121622 ],
#        ...,
#        [-0.11290737, -0.73869952,  0.73516966, ..., -0.07864911,
#          0.59908019, -1.3404457 ],
#        [-0.15103016, -0.83785009,  0.70159712, ..., -0.08537597,
#          0.60404033, -1.48183735],
#        [-0.26021935, -0.56292417,  0.76060349, ..., -0.07318763,
#          0.45957438, -0.76048585]]), 'bv': array([[ 0.55189864],
#        [ 0.54922417],
#        [ 0.51973127],
#        [ 0.51256282],
#        [ 0.50053639],
#        [ 0.5002098 ],
#        [ 0.49118749],
#        [ 0.54254183],
#        [ 0.50415519],
#        [ 0.53172128],
#        [ 0.52079947],
#        [ 0.53918812],
#        [ 0.56816354],
#        [ 0.5326313 ],
#        [ 0.59617085],
#        [ 0.56252291],
#        [ 0.59518584],
#        [ 0.58227777],
#        [ 0.64526329],
#        [ 0.6213892 ],
#        [ 0.59747438],
#        [ 0.62027923],
#        [ 0.62259522],
#        [ 0.60561448],
#        [ 0.59368882],
#        [ 0.56752739],
#        [ 0.55787008],
#        [ 0.53089869],
#        [ 0.51498567],
#        [ 0.49288713],
#        [ 0.48849207],
#        [ 0.4636246 ],
#        [ 0.47320018],
#        [ 0.46288856],
#        [ 0.4626002 ],
#        [ 0.46995555],
#        [ 0.46717562],
#        [ 0.47840668],
#        [ 0.49168483],
#        [ 0.48868243],
#        [ 0.47734584],
#        [ 0.48016398],
#        [ 0.47598396],
#        [ 0.47113257],
#        [ 0.44080329],
#        [ 0.4421051 ],
#        [ 0.40831304],
#        [ 0.42784808],
#        [ 0.37786855],
#        [ 0.35817532],
#        [ 0.36805481],
#        [ 0.36292784],
#        [ 0.33541225],
#        [ 0.32845705],
#        [ 0.28048248],
#        [ 0.23400518],
#        [ 0.1819498 ],
#        [ 0.18886013],
#        [ 0.16269289],
#        [ 0.16321538],
#        [ 0.11933747],
#        [ 0.12267769],
#        [ 0.10109346],
#        [ 0.07707441],
#        [ 0.04868918],
#        [ 0.04872541],
#        [ 0.02599036],
#        [ 0.00274455],
#        [ 0.00214734],
#        [ 0.01488596],
#        [-0.00264986],
#        [-0.01427478],
#        [ 0.00837774],
#        [-0.02074682],
#        [-0.01881659],
#        [-0.03379416],
#        [-0.03887706],
#        [-0.08588603],
#        [-0.06599652],
#        [-0.09646249],
#        [-0.10248796],
#        [-0.12767899],
#        [-0.14180263],
#        [-0.14824418],
#        [-0.17352435],
#        [-0.16810656],
#        [-0.20085508],
#        [-0.21013467],
#        [-0.20077239],
#        [-0.21941318],
#        [-0.23137729],
#        [-0.26626499],
#        [-0.2540237 ],
#        [-0.2579765 ],
#        [-0.27554517],
#        [-0.277851  ],
#        [-0.29158627],
#        [-0.29255974],
#        [-0.30855943],
#        [-0.28638549],
#        [-0.49234609]])}, {'Wf': array([[-0.18564977,  0.0322141 , -0.04818845, ..., -0.12048841,
#          0.09804777,  0.05325   ],
#        [-0.06109197,  0.09811411, -0.04168961, ...,  0.08114126,
#          0.08047905,  0.05512676],
#        [-0.12158022, -0.13627538, -0.17668155, ..., -0.20193493,
#          0.20272957,  0.12999881],
#        ...,
#        [ 0.01255876,  0.16984161,  0.03624951, ..., -0.08108413,
#          0.04121908,  0.00478767],
#        [ 0.02036318,  0.06390896, -0.02934949, ...,  0.06846599,
#          0.09238949,  0.08252651],
#        [ 0.04791726,  0.01360442, -0.01159031, ...,  0.07645322,
#          0.05202115,  0.05020851]]), 'bf': array([[1.05032015],
#        [1.08373612],
#        [1.08920687],
#        [1.02828693],
#        [1.0825476 ],
#        [1.14573225],
#        [1.04020056],
#        [1.06803859],
#        [1.07327751],
#        [1.0113719 ],
#        [1.0307025 ],
#        [1.02641318],
#        [1.07471422],
#        [1.07047969],
#        [1.10095669],
#        [1.0111647 ],
#        [1.06367949],
#        [1.00765221],
#        [1.06906137],
#        [0.96677803],
#        [1.08039571],
#        [1.03641633],
#        [1.05174676],
#        [1.05926491],
#        [1.03266059],
#        [1.03454594],
#        [1.04518686],
#        [1.02190527],
#        [0.99047914],
#        [1.06126317],
#        [1.0231569 ],
#        [0.96593006],
#        [1.04133929],
#        [1.05839786],
#        [1.05678469],
#        [1.0367519 ],
#        [1.0780693 ],
#        [1.03939944],
#        [1.02982651],
#        [1.22984627],
#        [1.03927436],
#        [1.07138223],
#        [0.95980763],
#        [1.0829577 ],
#        [1.04272909],
#        [1.06227023],
#        [1.06841976],
#        [1.06722668],
#        [1.05371202],
#        [1.03970251],
#        [0.98573322],
#        [1.04839654],
#        [1.05071212],
#        [1.0469534 ],
#        [1.06516054],
#        [1.0706018 ],
#        [1.05523076],
#        [1.12127272],
#        [1.06043332],
#        [1.07008934],
#        [1.09667145],
#        [1.06153483],
#        [1.06684203],
#        [1.04942246],
#        [0.98643897],
#        [1.0601797 ],
#        [1.09068705],
#        [1.08716404],
#        [1.07461371],
#        [1.05921925],
#        [1.1096217 ],
#        [1.05080112],
#        [1.06219055],
#        [1.04544236],
#        [1.02574146],
#        [1.04223387],
#        [1.0789061 ],
#        [1.06871694],
#        [1.00216853],
#        [1.03048419],
#        [1.09819103],
#        [1.0339168 ],
#        [1.06167599],
#        [1.07701336],
#        [1.15397874],
#        [1.03744954],
#        [1.04158555],
#        [1.03149759],
#        [1.06037439],
#        [1.19617647],
#        [1.07607425],
#        [1.04414393],
#        [1.06219875],
#        [1.04168023],
#        [1.03966008],
#        [1.05335521],
#        [1.05828675],
#        [1.08734352],
#        [1.0850512 ],
#        [1.07113528]]), 'Wi': array([[-0.35876051,  0.06531404, -0.0810624 , ...,  0.00274041,
#          0.05487662,  0.05608973],
#        [-0.02115981,  0.16963216,  0.01860463, ..., -0.05882116,
#         -0.06700962, -0.05634284],
#        [-0.05834764,  0.09453896, -0.52647594, ..., -0.03518341,
#          0.02156149, -0.00295659],
#        ...,
#        [ 0.04369218,  0.13116003, -0.00631491, ...,  0.00607538,
#          0.0172913 ,  0.00894547],
#        [-0.03737363,  0.04248013, -0.05293714, ..., -0.01780473,
#          0.00229196,  0.01785574],
#        [ 0.19273605,  0.04437742, -0.06902674, ...,  0.10098549,
#          0.07390661,  0.08306758]]), 'bi': array([[1.06310218],
#        [0.92990866],
#        [1.00094982],
#        [1.01148314],
#        [0.91543413],
#        [1.0444907 ],
#        [1.07523039],
#        [1.02228579],
#        [1.02388617],
#        [1.04516746],
#        [1.01485734],
#        [1.05083217],
#        [0.92861285],
#        [0.89280231],
#        [0.90778182],
#        [0.98646694],
#        [0.88533849],
#        [1.08666432],
#        [1.09543124],
#        [1.08280484],
#        [0.93904937],
#        [0.99344404],
#        [1.07994221],
#        [0.98085908],
#        [1.07862968],
#        [1.01444385],
#        [1.01054248],
#        [1.01944683],
#        [0.91403935],
#        [1.09171777],
#        [1.01828847],
#        [0.93559894],
#        [0.86841702],
#        [0.9403288 ],
#        [0.92760146],
#        [0.92544675],
#        [1.08299736],
#        [0.98749211],
#        [1.01798561],
#        [1.03829483],
#        [1.06950872],
#        [1.06630134],
#        [0.96753854],
#        [1.01268341],
#        [0.89676864],
#        [1.01603013],
#        [1.01269679],
#        [1.08165328],
#        [0.99150468],
#        [0.96138165],
#        [1.10431166],
#        [1.01755167],
#        [1.04225208],
#        [1.02529198],
#        [1.02694045],
#        [0.98597997],
#        [1.08226956],
#        [1.12092312],
#        [0.9744185 ],
#        [1.08911062],
#        [0.89821867],
#        [0.9171116 ],
#        [1.03102649],
#        [1.05092667],
#        [1.05004195],
#        [1.00800867],
#        [1.05608546],
#        [0.93148772],
#        [1.01405444],
#        [1.08888074],
#        [1.04437569],
#        [1.03171239],
#        [0.99902858],
#        [0.95864753],
#        [0.95169849],
#        [1.05928478],
#        [1.09368392],
#        [0.9337258 ],
#        [0.91509546],
#        [0.89668974],
#        [0.93814484],
#        [0.99035026],
#        [1.03492126],
#        [1.08117836],
#        [1.01898899],
#        [0.99873661],
#        [1.04786245],
#        [1.05492367],
#        [1.08212118],
#        [1.04204744],
#        [1.03400105],
#        [0.99604101],
#        [1.01853205],
#        [0.94655013],
#        [0.93071023],
#        [0.8735768 ],
#        [1.00628304],
#        [1.02267514],
#        [0.99075036],
#        [1.07400993]]), 'Wc': array([[ 0.37616002,  0.02491891, -0.16121304, ..., -0.01979567,
#          0.03319335, -0.00905801],
#        [-0.05548154,  0.03803616, -0.08985911, ...,  0.00502674,
#          0.03138603, -0.00736547],
#        [-0.04201148, -0.48292646, -0.10278721, ..., -0.09180324,
#          0.06113852,  0.02728158],
#        ...,
#        [-0.11654761, -0.0104881 , -0.15111948, ...,  0.06422703,
#         -0.10138768, -0.08637677],
#        [ 0.09284664, -0.05476818,  0.17276274, ..., -0.01931532,
#         -0.02076231,  0.01510171],
#        [ 0.02327513,  0.01733433,  0.0549094 , ...,  0.05078404,
#          0.06554274,  0.05709571]]), 'bc': array([[1.03589755],
#        [1.01915656],
#        [1.03523764],
#        [1.02248092],
#        [1.02520051],
#        [1.04299373],
#        [0.94975647],
#        [1.02238728],
#        [1.02044663],
#        [1.1655931 ],
#        [0.97585952],
#        [1.05157461],
#        [0.99023144],
#        [0.94506799],
#        [1.04683025],
#        [1.0010047 ],
#        [1.00985231],
#        [0.94177456],
#        [1.03105369],
#        [0.94082989],
#        [1.02116679],
#        [0.95252642],
#        [1.05234621],
#        [0.97390832],
#        [1.05059981],
#        [0.97570774],
#        [1.01742244],
#        [0.94000179],
#        [0.95774629],
#        [0.97091481],
#        [1.01490546],
#        [1.0279857 ],
#        [1.00623192],
#        [0.97624643],
#        [1.01290159],
#        [0.98277848],
#        [0.9844326 ],
#        [1.03506707],
#        [1.01577092],
#        [1.14482741],
#        [0.93288968],
#        [0.98755631],
#        [1.0285273 ],
#        [0.95000179],
#        [0.96627523],
#        [0.97777189],
#        [0.96324735],
#        [1.04001476],
#        [0.99964198],
#        [1.01066716],
#        [0.988613  ],
#        [0.95664921],
#        [0.97504551],
#        [0.96505431],
#        [0.98037449],
#        [0.93898289],
#        [1.04311048],
#        [0.96049968],
#        [1.01575065],
#        [1.05808651],
#        [1.05362685],
#        [1.03389352],
#        [0.93981673],
#        [0.97309158],
#        [1.07521014],
#        [0.94727507],
#        [1.02666901],
#        [1.04417164],
#        [0.95587008],
#        [1.01558597],
#        [1.01345543],
#        [0.95053742],
#        [1.0097536 ],
#        [0.97210992],
#        [0.98224041],
#        [1.04193398],
#        [1.04426981],
#        [1.02272641],
#        [1.01569378],
#        [1.01828445],
#        [1.03590943],
#        [0.96554822],
#        [1.03350835],
#        [1.06092297],
#        [1.0576234 ],
#        [1.03997474],
#        [1.11441306],
#        [1.0260518 ],
#        [1.04732082],
#        [0.95708873],
#        [0.96839852],
#        [0.94005503],
#        [0.97872314],
#        [1.02740615],
#        [0.95679057],
#        [1.01381791],
#        [0.99446321],
#        [0.87571497],
#        [1.0007616 ],
#        [1.05591098]]), 'Wo': array([[-0.07029353,  0.08007363, -0.11357934, ...,  0.07795353,
#          0.10019695,  0.08088321],
#        [ 0.15905675,  0.09932922, -0.10309724, ...,  0.02991522,
#          0.05857103,  0.04865553],
#        [-0.29251172, -0.05999288, -0.27306726, ..., -0.03054881,
#          0.1350382 ,  0.14812509],
#        ...,
#        [ 0.08772661,  0.10673849, -0.00115548, ...,  0.04290671,
#          0.06545332,  0.0763722 ],
#        [ 0.04237087, -0.08847114, -0.13073105, ..., -0.20042277,
#          0.1409413 ,  0.11217493],
#        [-0.00465607, -0.04759776,  0.09463798, ...,  0.07904445,
#         -0.17132684, -0.08295297]]), 'bo': array([[1.08483459],
#        [1.01442682],
#        [1.05505123],
#        [1.06302764],
#        [1.01167186],
#        [1.07951384],
#        [0.94896253],
#        [0.99405769],
#        [0.98760615],
#        [1.08418421],
#        [1.05841547],
#        [1.04842251],
#        [1.00759666],
#        [1.05535328],
#        [1.00678728],
#        [0.99191856],
#        [1.05720347],
#        [1.02658226],
#        [1.01987389],
#        [1.02017922],
#        [1.02790269],
#        [0.91845656],
#        [0.96300877],
#        [1.0788484 ],
#        [0.96535852],
#        [1.07945143],
#        [1.06165371],
#        [1.10206712],
#        [1.04604272],
#        [0.99262183],
#        [1.04192852],
#        [0.94856452],
#        [1.01057044],
#        [1.0526348 ],
#        [1.00750781],
#        [1.03677126],
#        [1.09536193],
#        [1.03911276],
#        [0.99722213],
#        [1.03709059],
#        [1.10294905],
#        [1.08686586],
#        [1.12098127],
#        [0.9799658 ],
#        [1.03306697],
#        [1.08063732],
#        [0.96981011],
#        [0.90780337],
#        [1.0869364 ],
#        [1.03806227],
#        [1.03582956],
#        [0.96907334],
#        [1.07658574],
#        [1.00371491],
#        [1.07048012],
#        [1.0667711 ],
#        [0.98352455],
#        [1.10008805],
#        [1.02106115],
#        [0.94118526],
#        [1.02049945],
#        [1.06117039],
#        [0.99869695],
#        [1.00320191],
#        [1.02055282],
#        [0.99612243],
#        [1.10574692],
#        [0.99426786],
#        [1.02786473],
#        [0.98043052],
#        [1.11625467],
#        [1.02060557],
#        [1.00993411],
#        [1.09183542],
#        [1.05379105],
#        [0.9777543 ],
#        [0.96852636],
#        [1.01553117],
#        [1.03125061],
#        [0.97970334],
#        [0.99001403],
#        [1.08278532],
#        [0.94347595],
#        [0.97013913],
#        [0.99236927],
#        [1.08182622],
#        [1.00267792],
#        [1.05509985],
#        [0.98642501],
#        [1.04115096],
#        [1.00331833],
#        [0.91396723],
#        [1.07651437],
#        [1.07237476],
#        [0.99770155],
#        [1.01506561],
#        [1.11002575],
#        [1.07522041],
#        [1.04765811],
#        [0.95166721]]), 'Wv': array([[-0.2386224 , -0.1976348 ,  1.51062579, ...,  0.15778947,
#          1.06544564, -0.12085933],
#        [-0.24415036, -0.29229287,  1.44721086, ...,  0.19354405,
#          0.89592646, -0.11803306],
#        [-0.24768419, -0.25671892,  1.33293496, ...,  0.18161202,
#          0.84000461, -0.2121622 ],
#        ...,
#        [-0.11290737, -0.73869952,  0.73516966, ..., -0.07864911,
#          0.59908019, -1.3404457 ],
#        [-0.15103016, -0.83785009,  0.70159712, ..., -0.08537597,
#          0.60404033, -1.48183735],
#        [-0.26021935, -0.56292417,  0.76060349, ..., -0.07318763,
#          0.45957438, -0.76048585]]), 'bv': array([[ 0.55189864],
#        [ 0.54922417],
#        [ 0.51973127],
#        [ 0.51256282],
#        [ 0.50053639],
#        [ 0.5002098 ],
#        [ 0.49118749],
#        [ 0.54254183],
#        [ 0.50415519],
#        [ 0.53172128],
#        [ 0.52079947],
#        [ 0.53918812],
#        [ 0.56816354],
#        [ 0.5326313 ],
#        [ 0.59617085],
#        [ 0.56252291],
#        [ 0.59518584],
#        [ 0.58227777],
#        [ 0.64526329],
#        [ 0.6213892 ],
#        [ 0.59747438],
#        [ 0.62027923],
#        [ 0.62259522],
#        [ 0.60561448],
#        [ 0.59368882],
#        [ 0.56752739],
#        [ 0.55787008],
#        [ 0.53089869],
#        [ 0.51498567],
#        [ 0.49288713],
#        [ 0.48849207],
#        [ 0.4636246 ],
#        [ 0.47320018],
#        [ 0.46288856],
#        [ 0.4626002 ],
#        [ 0.46995555],
#        [ 0.46717562],
#        [ 0.47840668],
#        [ 0.49168483],
#        [ 0.48868243],
#        [ 0.47734584],
#        [ 0.48016398],
#        [ 0.47598396],
#        [ 0.47113257],
#        [ 0.44080329],
#        [ 0.4421051 ],
#        [ 0.40831304],
#        [ 0.42784808],
#        [ 0.37786855],
#        [ 0.35817532],
#        [ 0.36805481],
#        [ 0.36292784],
#        [ 0.33541225],
#        [ 0.32845705],
#        [ 0.28048248],
#        [ 0.23400518],
#        [ 0.1819498 ],
#        [ 0.18886013],
#        [ 0.16269289],
#        [ 0.16321538],
#        [ 0.11933747],
#        [ 0.12267769],
#        [ 0.10109346],
#        [ 0.07707441],
#        [ 0.04868918],
#        [ 0.04872541],
#        [ 0.02599036],
#        [ 0.00274455],
#        [ 0.00214734],
#        [ 0.01488596],
#        [-0.00264986],
#        [-0.01427478],
#        [ 0.00837774],
#        [-0.02074682],
#        [-0.01881659],
#        [-0.03379416],
#        [-0.03887706],
#        [-0.08588603],
#        [-0.06599652],
#        [-0.09646249],
#        [-0.10248796],
#        [-0.12767899],
#        [-0.14180263],
#        [-0.14824418],
#        [-0.17352435],
#        [-0.16810656],
#        [-0.20085508],
#        [-0.21013467],
#        [-0.20077239],
#        [-0.21941318],
#        [-0.23137729],
#        [-0.26626499],
#        [-0.2540237 ],
#        [-0.2579765 ],
#        [-0.27554517],
#        [-0.277851  ],
#        [-0.29158627],
#        [-0.29255974],
#        [-0.30855943],
#        [-0.28638549],
#        [-0.49234609]])}, {'Wf': array([[-0.18564977,  0.0322141 , -0.04818845, ..., -0.12048841,
#          0.09804777,  0.05325   ],
#        [-0.06109197,  0.09811411, -0.04168961, ...,  0.08114126,
#          0.08047905,  0.05512676],
#        [-0.12158022, -0.13627538, -0.17668155, ..., -0.20193493,
#          0.20272957,  0.12999881],
#        ...,
#        [ 0.01255876,  0.16984161,  0.03624951, ..., -0.08108413,
#          0.04121908,  0.00478767],
#        [ 0.02036318,  0.06390896, -0.02934949, ...,  0.06846599,
#          0.09238949,  0.08252651],
#        [ 0.04791726,  0.01360442, -0.01159031, ...,  0.07645322,
#          0.05202115,  0.05020851]]), 'bf': array([[1.05032015],
#        [1.08373612],
#        [1.08920687],
#        [1.02828693],
#        [1.0825476 ],
#        [1.14573225],
#        [1.04020056],
#        [1.06803859],
#        [1.07327751],
#        [1.0113719 ],
#        [1.0307025 ],
#        [1.02641318],
#        [1.07471422],
#        [1.07047969],
#        [1.10095669],
#        [1.0111647 ],
#        [1.06367949],
#        [1.00765221],
#        [1.06906137],
#        [0.96677803],
#        [1.08039571],
#        [1.03641633],
#        [1.05174676],
#        [1.05926491],
#        [1.03266059],
#        [1.03454594],
#        [1.04518686],
#        [1.02190527],
#        [0.99047914],
#        [1.06126317],
#        [1.0231569 ],
#        [0.96593006],
#        [1.04133929],
#        [1.05839786],
#        [1.05678469],
#        [1.0367519 ],
#        [1.0780693 ],
#        [1.03939944],
#        [1.02982651],
#        [1.22984627],
#        [1.03927436],
#        [1.07138223],
#        [0.95980763],
#        [1.0829577 ],
#        [1.04272909],
#        [1.06227023],
#        [1.06841976],
#        [1.06722668],
#        [1.05371202],
#        [1.03970251],
#        [0.98573322],
#        [1.04839654],
#        [1.05071212],
#        [1.0469534 ],
#        [1.06516054],
#        [1.0706018 ],
#        [1.05523076],
#        [1.12127272],
#        [1.06043332],
#        [1.07008934],
#        [1.09667145],
#        [1.06153483],
#        [1.06684203],
#        [1.04942246],
#        [0.98643897],
#        [1.0601797 ],
#        [1.09068705],
#        [1.08716404],
#        [1.07461371],
#        [1.05921925],
#        [1.1096217 ],
#        [1.05080112],
#        [1.06219055],
#        [1.04544236],
#        [1.02574146],
#        [1.04223387],
#        [1.0789061 ],
#        [1.06871694],
#        [1.00216853],
#        [1.03048419],
#        [1.09819103],
#        [1.0339168 ],
#        [1.06167599],
#        [1.07701336],
#        [1.15397874],
#        [1.03744954],
#        [1.04158555],
#        [1.03149759],
#        [1.06037439],
#        [1.19617647],
#        [1.07607425],
#        [1.04414393],
#        [1.06219875],
#        [1.04168023],
#        [1.03966008],
#        [1.05335521],
#        [1.05828675],
#        [1.08734352],
#        [1.0850512 ],
#        [1.07113528]]), 'Wi': array([[-0.35876051,  0.06531404, -0.0810624 , ...,  0.00274041,
#          0.05487662,  0.05608973],
#        [-0.02115981,  0.16963216,  0.01860463, ..., -0.05882116,
#         -0.06700962, -0.05634284],
#        [-0.05834764,  0.09453896, -0.52647594, ..., -0.03518341,
#          0.02156149, -0.00295659],
#        ...,
#        [ 0.04369218,  0.13116003, -0.00631491, ...,  0.00607538,
#          0.0172913 ,  0.00894547],
#        [-0.03737363,  0.04248013, -0.05293714, ..., -0.01780473,
#          0.00229196,  0.01785574],
#        [ 0.19273605,  0.04437742, -0.06902674, ...,  0.10098549,
#          0.07390661,  0.08306758]]), 'bi': array([[1.06310218],
#        [0.92990866],
#        [1.00094982],
#        [1.01148314],
#        [0.91543413],
#        [1.0444907 ],
#        [1.07523039],
#        [1.02228579],
#        [1.02388617],
#        [1.04516746],
#        [1.01485734],
#        [1.05083217],
#        [0.92861285],
#        [0.89280231],
#        [0.90778182],
#        [0.98646694],
#        [0.88533849],
#        [1.08666432],
#        [1.09543124],
#        [1.08280484],
#        [0.93904937],
#        [0.99344404],
#        [1.07994221],
#        [0.98085908],
#        [1.07862968],
#        [1.01444385],
#        [1.01054248],
#        [1.01944683],
#        [0.91403935],
#        [1.09171777],
#        [1.01828847],
#        [0.93559894],
#        [0.86841702],
#        [0.9403288 ],
#        [0.92760146],
#        [0.92544675],
#        [1.08299736],
#        [0.98749211],
#        [1.01798561],
#        [1.03829483],
#        [1.06950872],
#        [1.06630134],
#        [0.96753854],
#        [1.01268341],
#        [0.89676864],
#        [1.01603013],
#        [1.01269679],
#        [1.08165328],
#        [0.99150468],
#        [0.96138165],
#        [1.10431166],
#        [1.01755167],
#        [1.04225208],
#        [1.02529198],
#        [1.02694045],
#        [0.98597997],
#        [1.08226956],
#        [1.12092312],
#        [0.9744185 ],
#        [1.08911062],
#        [0.89821867],
#        [0.9171116 ],
#        [1.03102649],
#        [1.05092667],
#        [1.05004195],
#        [1.00800867],
#        [1.05608546],
#        [0.93148772],
#        [1.01405444],
#        [1.08888074],
#        [1.04437569],
#        [1.03171239],
#        [0.99902858],
#        [0.95864753],
#        [0.95169849],
#        [1.05928478],
#        [1.09368392],
#        [0.9337258 ],
#        [0.91509546],
#        [0.89668974],
#        [0.93814484],
#        [0.99035026],
#        [1.03492126],
#        [1.08117836],
#        [1.01898899],
#        [0.99873661],
#        [1.04786245],
#        [1.05492367],
#        [1.08212118],
#        [1.04204744],
#        [1.03400105],
#        [0.99604101],
#        [1.01853205],
#        [0.94655013],
#        [0.93071023],
#        [0.8735768 ],
#        [1.00628304],
#        [1.02267514],
#        [0.99075036],
#        [1.07400993]]), 'Wc': array([[ 0.37616002,  0.02491891, -0.16121304, ..., -0.01979567,
#          0.03319335, -0.00905801],
#        [-0.05548154,  0.03803616, -0.08985911, ...,  0.00502674,
#          0.03138603, -0.00736547],
#        [-0.04201148, -0.48292646, -0.10278721, ..., -0.09180324,
#          0.06113852,  0.02728158],
#        ...,
#        [-0.11654761, -0.0104881 , -0.15111948, ...,  0.06422703,
#         -0.10138768, -0.08637677],
#        [ 0.09284664, -0.05476818,  0.17276274, ..., -0.01931532,
#         -0.02076231,  0.01510171],
#        [ 0.02327513,  0.01733433,  0.0549094 , ...,  0.05078404,
#          0.06554274,  0.05709571]]), 'bc': array([[1.03589755],
#        [1.01915656],
#        [1.03523764],
#        [1.02248092],
#        [1.02520051],
#        [1.04299373],
#        [0.94975647],
#        [1.02238728],
#        [1.02044663],
#        [1.1655931 ],
#        [0.97585952],
#        [1.05157461],
#        [0.99023144],
#        [0.94506799],
#        [1.04683025],
#        [1.0010047 ],
#        [1.00985231],
#        [0.94177456],
#        [1.03105369],
#        [0.94082989],
#        [1.02116679],
#        [0.95252642],
#        [1.05234621],
#        [0.97390832],
#        [1.05059981],
#        [0.97570774],
#        [1.01742244],
#        [0.94000179],
#        [0.95774629],
#        [0.97091481],
#        [1.01490546],
#        [1.0279857 ],
#        [1.00623192],
#        [0.97624643],
#        [1.01290159],
#        [0.98277848],
#        [0.9844326 ],
#        [1.03506707],
#        [1.01577092],
#        [1.14482741],
#        [0.93288968],
#        [0.98755631],
#        [1.0285273 ],
#        [0.95000179],
#        [0.96627523],
#        [0.97777189],
#        [0.96324735],
#        [1.04001476],
#        [0.99964198],
#        [1.01066716],
#        [0.988613  ],
#        [0.95664921],
#        [0.97504551],
#        [0.96505431],
#        [0.98037449],
#        [0.93898289],
#        [1.04311048],
#        [0.96049968],
#        [1.01575065],
#        [1.05808651],
#        [1.05362685],
#        [1.03389352],
#        [0.93981673],
#        [0.97309158],
#        [1.07521014],
#        [0.94727507],
#        [1.02666901],
#        [1.04417164],
#        [0.95587008],
#        [1.01558597],
#        [1.01345543],
#        [0.95053742],
#        [1.0097536 ],
#        [0.97210992],
#        [0.98224041],
#        [1.04193398],
#        [1.04426981],
#        [1.02272641],
#        [1.01569378],
#        [1.01828445],
#        [1.03590943],
#        [0.96554822],
#        [1.03350835],
#        [1.06092297],
#        [1.0576234 ],
#        [1.03997474],
#        [1.11441306],
#        [1.0260518 ],
#        [1.04732082],
#        [0.95708873],
#        [0.96839852],
#        [0.94005503],
#        [0.97872314],
#        [1.02740615],
#        [0.95679057],
#        [1.01381791],
#        [0.99446321],
#        [0.87571497],
#        [1.0007616 ],
#        [1.05591098]]), 'Wo': array([[-0.07029353,  0.08007363, -0.11357934, ...,  0.07795353,
#          0.10019695,  0.08088321],
#        [ 0.15905675,  0.09932922, -0.10309724, ...,  0.02991522,
#          0.05857103,  0.04865553],
#        [-0.29251172, -0.05999288, -0.27306726, ..., -0.03054881,
#          0.1350382 ,  0.14812509],
#        ...,
#        [ 0.08772661,  0.10673849, -0.00115548, ...,  0.04290671,
#          0.06545332,  0.0763722 ],
#        [ 0.04237087, -0.08847114, -0.13073105, ..., -0.20042277,
#          0.1409413 ,  0.11217493],
#        [-0.00465607, -0.04759776,  0.09463798, ...,  0.07904445,
#         -0.17132684, -0.08295297]]), 'bo': array([[1.08483459],
#        [1.01442682],
#        [1.05505123],
#        [1.06302764],
#        [1.01167186],
#        [1.07951384],
#        [0.94896253],
#        [0.99405769],
#        [0.98760615],
#        [1.08418421],
#        [1.05841547],
#        [1.04842251],
#        [1.00759666],
#        [1.05535328],
#        [1.00678728],
#        [0.99191856],
#        [1.05720347],
#        [1.02658226],
#        [1.01987389],
#        [1.02017922],
#        [1.02790269],
#        [0.91845656],
#        [0.96300877],
#        [1.0788484 ],
#        [0.96535852],
#        [1.07945143],
#        [1.06165371],
#        [1.10206712],
#        [1.04604272],
#        [0.99262183],
#        [1.04192852],
#        [0.94856452],
#        [1.01057044],
#        [1.0526348 ],
#        [1.00750781],
#        [1.03677126],
#        [1.09536193],
#        [1.03911276],
#        [0.99722213],
#        [1.03709059],
#        [1.10294905],
#        [1.08686586],
#        [1.12098127],
#        [0.9799658 ],
#        [1.03306697],
#        [1.08063732],
#        [0.96981011],
#        [0.90780337],
#        [1.0869364 ],
#        [1.03806227],
#        [1.03582956],
#        [0.96907334],
#        [1.07658574],
#        [1.00371491],
#        [1.07048012],
#        [1.0667711 ],
#        [0.98352455],
#        [1.10008805],
#        [1.02106115],
#        [0.94118526],
#        [1.02049945],
#        [1.06117039],
#        [0.99869695],
#        [1.00320191],
#        [1.02055282],
#        [0.99612243],
#        [1.10574692],
#        [0.99426786],
#        [1.02786473],
#        [0.98043052],
#        [1.11625467],
#        [1.02060557],
#        [1.00993411],
#        [1.09183542],
#        [1.05379105],
#        [0.9777543 ],
#        [0.96852636],
#        [1.01553117],
#        [1.03125061],
#        [0.97970334],
#        [0.99001403],
#        [1.08278532],
#        [0.94347595],
#        [0.97013913],
#        [0.99236927],
#        [1.08182622],
#        [1.00267792],
#        [1.05509985],
#        [0.98642501],
#        [1.04115096],
#        [1.00331833],
#        [0.91396723],
#        [1.07651437],
#        [1.07237476],
#        [0.99770155],
#        [1.01506561],
#        [1.11002575],
#        [1.07522041],
#        [1.04765811],
#        [0.95166721]]), 'Wv': array([[-0.2386224 , -0.1976348 ,  1.51062579, ...,  0.15778947,
#          1.06544564, -0.12085933],
#        [-0.24415036, -0.29229287,  1.44721086, ...,  0.19354405,
#          0.89592646, -0.11803306],
#        [-0.24768419, -0.25671892,  1.33293496, ...,  0.18161202,
#          0.84000461, -0.2121622 ],
#        ...,
#        [-0.11290737, -0.73869952,  0.73516966, ..., -0.07864911,
#          0.59908019, -1.3404457 ],
#        [-0.15103016, -0.83785009,  0.70159712, ..., -0.08537597,
#          0.60404033, -1.48183735],
#        [-0.26021935, -0.56292417,  0.76060349, ..., -0.07318763,
#          0.45957438, -0.76048585]]), 'bv': array([[ 0.55189864],
#        [ 0.54922417],
#        [ 0.51973127],
#        [ 0.51256282],
#        [ 0.50053639],
#        [ 0.5002098 ],
#        [ 0.49118749],
#        [ 0.54254183],
#        [ 0.50415519],
#        [ 0.53172128],
#        [ 0.52079947],
#        [ 0.53918812],
#        [ 0.56816354],
#        [ 0.5326313 ],
#        [ 0.59617085],
#        [ 0.56252291],
#        [ 0.59518584],
#        [ 0.58227777],
#        [ 0.64526329],
#        [ 0.6213892 ],
#        [ 0.59747438],
#        [ 0.62027923],
#        [ 0.62259522],
#        [ 0.60561448],
#        [ 0.59368882],
#        [ 0.56752739],
#        [ 0.55787008],
#        [ 0.53089869],
#        [ 0.51498567],
#        [ 0.49288713],
#        [ 0.48849207],
#        [ 0.4636246 ],
#        [ 0.47320018],
#        [ 0.46288856],
#        [ 0.4626002 ],
#        [ 0.46995555],
#        [ 0.46717562],
#        [ 0.47840668],
#        [ 0.49168483],
#        [ 0.48868243],
#        [ 0.47734584],
#        [ 0.48016398],
#        [ 0.47598396],
#        [ 0.47113257],
#        [ 0.44080329],
#        [ 0.4421051 ],
#        [ 0.40831304],
#        [ 0.42784808],
#        [ 0.37786855],
#        [ 0.35817532],
#        [ 0.36805481],
#        [ 0.36292784],
#        [ 0.33541225],
#        [ 0.32845705],
#        [ 0.28048248],
#        [ 0.23400518],
#        [ 0.1819498 ],
#        [ 0.18886013],
#        [ 0.16269289],
#        [ 0.16321538],
#        [ 0.11933747],
#        [ 0.12267769],
#        [ 0.10109346],
#        [ 0.07707441],
#        [ 0.04868918],
#        [ 0.04872541],
#        [ 0.02599036],
#        [ 0.00274455],
#        [ 0.00214734],
#        [ 0.01488596],
#        [-0.00264986],
#        [-0.01427478],
#        [ 0.00837774],
#        [-0.02074682],
#        [-0.01881659],
#        [-0.03379416],
#        [-0.03887706],
#        [-0.08588603],
#        [-0.06599652],
#        [-0.09646249],
#        [-0.10248796],
#        [-0.12767899],
#        [-0.14180263],
#        [-0.14824418],
#        [-0.17352435],
#        [-0.16810656],
#        [-0.20085508],
#        [-0.21013467],
#        [-0.20077239],
#        [-0.21941318],
#        [-0.23137729],
#        [-0.26626499],
#        [-0.2540237 ],
#        [-0.2579765 ],
#        [-0.27554517],
#        [-0.277851  ],
#        [-0.29158627],
#        [-0.29255974],
#        [-0.30855943],
#        [-0.28638549],
#        [-0.49234609]])}, {'Wf': array([[-0.18564977,  0.0322141 , -0.04818845, ..., -0.12048841,
#          0.09804777,  0.05325   ],
#        [-0.06109197,  0.09811411, -0.04168961, ...,  0.08114126,
#          0.08047905,  0.05512676],
#        [-0.12158022, -0.13627538, -0.17668155, ..., -0.20193493,
#          0.20272957,  0.12999881],
#        ...,
#        [ 0.01255876,  0.16984161,  0.03624951, ..., -0.08108413,
#          0.04121908,  0.00478767],
#        [ 0.02036318,  0.06390896, -0.02934949, ...,  0.06846599,
#          0.09238949,  0.08252651],
#        [ 0.04791726,  0.01360442, -0.01159031, ...,  0.07645322,
#          0.05202115,  0.05020851]]), 'bf': array([[1.05032015],
#        [1.08373612],
#        [1.08920687],
#        [1.02828693],
#        [1.0825476 ],
#        [1.14573225],
#        [1.04020056],
#        [1.06803859],
#        [1.07327751],
#        [1.0113719 ],
#        [1.0307025 ],
#        [1.02641318],
#        [1.07471422],
#        [1.07047969],
#        [1.10095669],
#        [1.0111647 ],
#        [1.06367949],
#        [1.00765221],
#        [1.06906137],
#        [0.96677803],
#        [1.08039571],
#        [1.03641633],
#        [1.05174676],
#        [1.05926491],
#        [1.03266059],
#        [1.03454594],
#        [1.04518686],
#        [1.02190527],
#        [0.99047914],
#        [1.06126317],
#        [1.0231569 ],
#        [0.96593006],
#        [1.04133929],
#        [1.05839786],
#        [1.05678469],
#        [1.0367519 ],
#        [1.0780693 ],
#        [1.03939944],
#        [1.02982651],
#        [1.22984627],
#        [1.03927436],
#        [1.07138223],
#        [0.95980763],
#        [1.0829577 ],
#        [1.04272909],
#        [1.06227023],
#        [1.06841976],
#        [1.06722668],
#        [1.05371202],
#        [1.03970251],
#        [0.98573322],
#        [1.04839654],
#        [1.05071212],
#        [1.0469534 ],
#        [1.06516054],
#        [1.0706018 ],
#        [1.05523076],
#        [1.12127272],
#        [1.06043332],
#        [1.07008934],
#        [1.09667145],
#        [1.06153483],
#        [1.06684203],
#        [1.04942246],
#        [0.98643897],
#        [1.0601797 ],
#        [1.09068705],
#        [1.08716404],
#        [1.07461371],
#        [1.05921925],
#        [1.1096217 ],
#        [1.05080112],
#        [1.06219055],
#        [1.04544236],
#        [1.02574146],
#        [1.04223387],
#        [1.0789061 ],
#        [1.06871694],
#        [1.00216853],
#        [1.03048419],
#        [1.09819103],
#        [1.0339168 ],
#        [1.06167599],
#        [1.07701336],
#        [1.15397874],
#        [1.03744954],
#        [1.04158555],
#        [1.03149759],
#        [1.06037439],
#        [1.19617647],
#        [1.07607425],
#        [1.04414393],
#        [1.06219875],
#        [1.04168023],
#        [1.03966008],
#        [1.05335521],
#        [1.05828675],
#        [1.08734352],
#        [1.0850512 ],
#        [1.07113528]]), 'Wi': array([[-0.35876051,  0.06531404, -0.0810624 , ...,  0.00274041,
#          0.05487662,  0.05608973],
#        [-0.02115981,  0.16963216,  0.01860463, ..., -0.05882116,
#         -0.06700962, -0.05634284],
#        [-0.05834764,  0.09453896, -0.52647594, ..., -0.03518341,
#          0.02156149, -0.00295659],
#        ...,
#        [ 0.04369218,  0.13116003, -0.00631491, ...,  0.00607538,
#          0.0172913 ,  0.00894547],
#        [-0.03737363,  0.04248013, -0.05293714, ..., -0.01780473,
#          0.00229196,  0.01785574],
#        [ 0.19273605,  0.04437742, -0.06902674, ...,  0.10098549,
#          0.07390661,  0.08306758]]), 'bi': array([[1.06310218],
#        [0.92990866],
#        [1.00094982],
#        [1.01148314],
#        [0.91543413],
#        [1.0444907 ],
#        [1.07523039],
#        [1.02228579],
#        [1.02388617],
#        [1.04516746],
#        [1.01485734],
#        [1.05083217],
#        [0.92861285],
#        [0.89280231],
#        [0.90778182],
#        [0.98646694],
#        [0.88533849],
#        [1.08666432],
#        [1.09543124],
#        [1.08280484],
#        [0.93904937],
#        [0.99344404],
#        [1.07994221],
#        [0.98085908],
#        [1.07862968],
#        [1.01444385],
#        [1.01054248],
#        [1.01944683],
#        [0.91403935],
#        [1.09171777],
#        [1.01828847],
#        [0.93559894],
#        [0.86841702],
#        [0.9403288 ],
#        [0.92760146],
#        [0.92544675],
#        [1.08299736],
#        [0.98749211],
#        [1.01798561],
#        [1.03829483],
#        [1.06950872],
#        [1.06630134],
#        [0.96753854],
#        [1.01268341],
#        [0.89676864],
#        [1.01603013],
#        [1.01269679],
#        [1.08165328],
#        [0.99150468],
#        [0.96138165],
#        [1.10431166],
#        [1.01755167],
#        [1.04225208],
#        [1.02529198],
#        [1.02694045],
#        [0.98597997],
#        [1.08226956],
#        [1.12092312],
#        [0.9744185 ],
#        [1.08911062],
#        [0.89821867],
#        [0.9171116 ],
#        [1.03102649],
#        [1.05092667],
#        [1.05004195],
#        [1.00800867],
#        [1.05608546],
#        [0.93148772],
#        [1.01405444],
#        [1.08888074],
#        [1.04437569],
#        [1.03171239],
#        [0.99902858],
#        [0.95864753],
#        [0.95169849],
#        [1.05928478],
#        [1.09368392],
#        [0.9337258 ],
#        [0.91509546],
#        [0.89668974],
#        [0.93814484],
#        [0.99035026],
#        [1.03492126],
#        [1.08117836],
#        [1.01898899],
#        [0.99873661],
#        [1.04786245],
#        [1.05492367],
#        [1.08212118],
#        [1.04204744],
#        [1.03400105],
#        [0.99604101],
#        [1.01853205],
#        [0.94655013],
#        [0.93071023],
#        [0.8735768 ],
#        [1.00628304],
#        [1.02267514],
#        [0.99075036],
#        [1.07400993]]), 'Wc': array([[ 0.37616002,  0.02491891, -0.16121304, ..., -0.01979567,
#          0.03319335, -0.00905801],
#        [-0.05548154,  0.03803616, -0.08985911, ...,  0.00502674,
#          0.03138603, -0.00736547],
#        [-0.04201148, -0.48292646, -0.10278721, ..., -0.09180324,
#          0.06113852,  0.02728158],
#        ...,
#        [-0.11654761, -0.0104881 , -0.15111948, ...,  0.06422703,
#         -0.10138768, -0.08637677],
#        [ 0.09284664, -0.05476818,  0.17276274, ..., -0.01931532,
#         -0.02076231,  0.01510171],
#        [ 0.02327513,  0.01733433,  0.0549094 , ...,  0.05078404,
#          0.06554274,  0.05709571]]), 'bc': array([[1.03589755],
#        [1.01915656],
#        [1.03523764],
#        [1.02248092],
#        [1.02520051],
#        [1.04299373],
#        [0.94975647],
#        [1.02238728],
#        [1.02044663],
#        [1.1655931 ],
#        [0.97585952],
#        [1.05157461],
#        [0.99023144],
#        [0.94506799],
#        [1.04683025],
#        [1.0010047 ],
#        [1.00985231],
#        [0.94177456],
#        [1.03105369],
#        [0.94082989],
#        [1.02116679],
#        [0.95252642],
#        [1.05234621],
#        [0.97390832],
#        [1.05059981],
#        [0.97570774],
#        [1.01742244],
#        [0.94000179],
#        [0.95774629],
# ...
#        [ 0.54922417],
#        [ 0.51973127],
#        [ 0.51256282],
#        [ 0.50053639],
#        [ 0.5002098 ],
#        [ 0.49118749],
#        [ 0.54254183],
#        [ 0.50415519],
#        [ 0.53172128],
#        [ 0.52079947],
#        [ 0.53918812],
#        [ 0.56816354],
#        [ 0.5326313 ],
#        [ 0.59617085],
#        [ 0.56252291],
#        [ 0.59518584],
#        [ 0.58227777],
#        [ 0.64526329],
#        [ 0.6213892 ],
#        [ 0.59747438],
#        [ 0.62027923],
#        [ 0.62259522],
#        [ 0.60561448],
#        [ 0.59368882],
#        [ 0.56752739],
#        [ 0.55787008],
#        [ 0.53089869],
#        [ 0.51498567],
#        [ 0.49288713],
#        [ 0.48849207],
#        [ 0.4636246 ],
#        [ 0.47320018],
#        [ 0.46288856],
#        [ 0.4626002 ],
#        [ 0.46995555],
#        [ 0.46717562],
#        [ 0.47840668],
#        [ 0.49168483],
#        [ 0.48868243],
#        [ 0.47734584],
#        [ 0.48016398],
#        [ 0.47598396],
#        [ 0.47113257],
#        [ 0.44080329],
#        [ 0.4421051 ],
#        [ 0.40831304],
#        [ 0.42784808],
#        [ 0.37786855],
#        [ 0.35817532],
#        [ 0.36805481],
#        [ 0.36292784],
#        [ 0.33541225],
#        [ 0.32845705],
#        [ 0.28048248],
#        [ 0.23400518],
#        [ 0.1819498 ],
#        [ 0.18886013],
#        [ 0.16269289],
#        [ 0.16321538],
#        [ 0.11933747],
#        [ 0.12267769],
#        [ 0.10109346],
#        [ 0.07707441],
#        [ 0.04868918],
#        [ 0.04872541],
#        [ 0.02599036],
#        [ 0.00274455],
#        [ 0.00214734],
#        [ 0.01488596],
#        [-0.00264986],
#        [-0.01427478],
#        [ 0.00837774],
#        [-0.02074682],
#        [-0.01881659],
#        [-0.03379416],
#        [-0.03887706],
#        [-0.08588603],
#        [-0.06599652],
#        [-0.09646249],
#        [-0.10248796],
#        [-0.12767899],
#        [-0.14180263],
#        [-0.14824418],
#        [-0.17352435],
#        [-0.16810656],
#        [-0.20085508],
#        [-0.21013467],
#        [-0.20077239],
#        [-0.21941318],
#        [-0.23137729],
#        [-0.26626499],
#        [-0.2540237 ],
#        [-0.2579765 ],
#        [-0.27554517],
#        [-0.277851  ],
#        [-0.29158627],
#        [-0.29255974],
#        [-0.30855943],
#        [-0.28638549],
#        [-0.49234609]])}, {'Wf': array([[-0.18564977,  0.0322141 , -0.04818845, ..., -0.12048841,
#          0.09804777,  0.05325   ],
#        [-0.06109197,  0.09811411, -0.04168961, ...,  0.08114126,
#          0.08047905,  0.05512676],
#        [-0.12158022, -0.13627538, -0.17668155, ..., -0.20193493,
#          0.20272957,  0.12999881],
#        ...,
#        [ 0.01255876,  0.16984161,  0.03624951, ..., -0.08108413,
#          0.04121908,  0.00478767],
#        [ 0.02036318,  0.06390896, -0.02934949, ...,  0.06846599,
#          0.09238949,  0.08252651],
#        [ 0.04791726,  0.01360442, -0.01159031, ...,  0.07645322,
#          0.05202115,  0.05020851]]), 'bf': array([[1.05032015],
#        [1.08373612],
#        [1.08920687],
#        [1.02828693],
#        [1.0825476 ],
#        [1.14573225],
#        [1.04020056],
#        [1.06803859],
#        [1.07327751],
#        [1.0113719 ],
#        [1.0307025 ],
#        [1.02641318],
#        [1.07471422],
#        [1.07047969],
#        [1.10095669],
#        [1.0111647 ],
#        [1.06367949],
#        [1.00765221],
#        [1.06906137],
#        [0.96677803],
#        [1.08039571],
#        [1.03641633],
#        [1.05174676],
#        [1.05926491],
#        [1.03266059],
#        [1.03454594],
#        [1.04518686],
#        [1.02190527],
#        [0.99047914],
#        [1.06126317],
#        [1.0231569 ],
#        [0.96593006],
#        [1.04133929],
#        [1.05839786],
#        [1.05678469],
#        [1.0367519 ],
#        [1.0780693 ],
#        [1.03939944],
#        [1.02982651],
#        [1.22984627],
#        [1.03927436],
#        [1.07138223],
#        [0.95980763],
#        [1.0829577 ],
#        [1.04272909],
#        [1.06227023],
#        [1.06841976],
#        [1.06722668],
#        [1.05371202],
#        [1.03970251],
#        [0.98573322],
#        [1.04839654],
#        [1.05071212],
#        [1.0469534 ],
#        [1.06516054],
#        [1.0706018 ],
#        [1.05523076],
#        [1.12127272],
#        [1.06043332],
#        [1.07008934],
#        [1.09667145],
#        [1.06153483],
#        [1.06684203],
#        [1.04942246],
#        [0.98643897],
#        [1.0601797 ],
#        [1.09068705],
#        [1.08716404],
#        [1.07461371],
#        [1.05921925],
#        [1.1096217 ],
#        [1.05080112],
#        [1.06219055],
#        [1.04544236],
#        [1.02574146],
#        [1.04223387],
#        [1.0789061 ],
#        [1.06871694],
#        [1.00216853],
#        [1.03048419],
#        [1.09819103],
#        [1.0339168 ],
#        [1.06167599],
#        [1.07701336],
#        [1.15397874],
#        [1.03744954],
#        [1.04158555],
#        [1.03149759],
#        [1.06037439],
#        [1.19617647],
#        [1.07607425],
#        [1.04414393],
#        [1.06219875],
#        [1.04168023],
#        [1.03966008],
#        [1.05335521],
#        [1.05828675],
#        [1.08734352],
#        [1.0850512 ],
#        [1.07113528]]), 'Wi': array([[-0.35876051,  0.06531404, -0.0810624 , ...,  0.00274041,
#          0.05487662,  0.05608973],
#        [-0.02115981,  0.16963216,  0.01860463, ..., -0.05882116,
#         -0.06700962, -0.05634284],
#        [-0.05834764,  0.09453896, -0.52647594, ..., -0.03518341,
#          0.02156149, -0.00295659],
#        ...,
#        [ 0.04369218,  0.13116003, -0.00631491, ...,  0.00607538,
#          0.0172913 ,  0.00894547],
#        [-0.03737363,  0.04248013, -0.05293714, ..., -0.01780473,
#          0.00229196,  0.01785574],
#        [ 0.19273605,  0.04437742, -0.06902674, ...,  0.10098549,
#          0.07390661,  0.08306758]]), 'bi': array([[1.06310218],
#        [0.92990866],
#        [1.00094982],
#        [1.01148314],
#        [0.91543413],
#        [1.0444907 ],
#        [1.07523039],
#        [1.02228579],
#        [1.02388617],
#        [1.04516746],
#        [1.01485734],
#        [1.05083217],
#        [0.92861285],
#        [0.89280231],
#        [0.90778182],
#        [0.98646694],
#        [0.88533849],
#        [1.08666432],
#        [1.09543124],
#        [1.08280484],
#        [0.93904937],
#        [0.99344404],
#        [1.07994221],
#        [0.98085908],
#        [1.07862968],
#        [1.01444385],
#        [1.01054248],
#        [1.01944683],
#        [0.91403935],
#        [1.09171777],
#        [1.01828847],
#        [0.93559894],
#        [0.86841702],
#        [0.9403288 ],
#        [0.92760146],
#        [0.92544675],
#        [1.08299736],
#        [0.98749211],
#        [1.01798561],
#        [1.03829483],
#        [1.06950872],
#        [1.06630134],
#        [0.96753854],
#        [1.01268341],
#        [0.89676864],
#        [1.01603013],
#        [1.01269679],
#        [1.08165328],
#        [0.99150468],
#        [0.96138165],
#        [1.10431166],
#        [1.01755167],
#        [1.04225208],
#        [1.02529198],
#        [1.02694045],
#        [0.98597997],
#        [1.08226956],
#        [1.12092312],
#        [0.9744185 ],
#        [1.08911062],
#        [0.89821867],
#        [0.9171116 ],
#        [1.03102649],
#        [1.05092667],
#        [1.05004195],
#        [1.00800867],
#        [1.05608546],
#        [0.93148772],
#        [1.01405444],
#        [1.08888074],
#        [1.04437569],
#        [1.03171239],
#        [0.99902858],
#        [0.95864753],
#        [0.95169849],
#        [1.05928478],
#        [1.09368392],
#        [0.9337258 ],
#        [0.91509546],
#        [0.89668974],
#        [0.93814484],
#        [0.99035026],
#        [1.03492126],
#        [1.08117836],
#        [1.01898899],
#        [0.99873661],
#        [1.04786245],
#        [1.05492367],
#        [1.08212118],
#        [1.04204744],
#        [1.03400105],
#        [0.99604101],
#        [1.01853205],
#        [0.94655013],
#        [0.93071023],
#        [0.8735768 ],
#        [1.00628304],
#        [1.02267514],
#        [0.99075036],
#        [1.07400993]]), 'Wc': array([[ 0.37616002,  0.02491891, -0.16121304, ..., -0.01979567,
#          0.03319335, -0.00905801],
#        [-0.05548154,  0.03803616, -0.08985911, ...,  0.00502674,
#          0.03138603, -0.00736547],
#        [-0.04201148, -0.48292646, -0.10278721, ..., -0.09180324,
#          0.06113852,  0.02728158],
#        ...,
#        [-0.11654761, -0.0104881 , -0.15111948, ...,  0.06422703,
#         -0.10138768, -0.08637677],
#        [ 0.09284664, -0.05476818,  0.17276274, ..., -0.01931532,
#         -0.02076231,  0.01510171],
#        [ 0.02327513,  0.01733433,  0.0549094 , ...,  0.05078404,
#          0.06554274,  0.05709571]]), 'bc': array([[1.03589755],
#        [1.01915656],
#        [1.03523764],
#        [1.02248092],
#        [1.02520051],
#        [1.04299373],
#        [0.94975647],
#        [1.02238728],
#        [1.02044663],
#        [1.1655931 ],
#        [0.97585952],
#        [1.05157461],
#        [0.99023144],
#        [0.94506799],
#        [1.04683025],
#        [1.0010047 ],
#        [1.00985231],
#        [0.94177456],
#        [1.03105369],
#        [0.94082989],
#        [1.02116679],
#        [0.95252642],
#        [1.05234621],
#        [0.97390832],
#        [1.05059981],
#        [0.97570774],
#        [1.01742244],
#        [0.94000179],
#        [0.95774629],
#        [0.97091481],
#        [1.01490546],
#        [1.0279857 ],
#        [1.00623192],
#        [0.97624643],
#        [1.01290159],
#        [0.98277848],
#        [0.9844326 ],
#        [1.03506707],
#        [1.01577092],
#        [1.14482741],
#        [0.93288968],
#        [0.98755631],
#        [1.0285273 ],
#        [0.95000179],
#        [0.96627523],
#        [0.97777189],
#        [0.96324735],
#        [1.04001476],
#        [0.99964198],
#        [1.01066716],
#        [0.988613  ],
#        [0.95664921],
#        [0.97504551],
#        [0.96505431],
#        [0.98037449],
#        [0.93898289],
#        [1.04311048],
#        [0.96049968],
#        [1.01575065],
#        [1.05808651],
#        [1.05362685],
#        [1.03389352],
#        [0.93981673],
#        [0.97309158],
#        [1.07521014],
#        [0.94727507],
#        [1.02666901],
#        [1.04417164],
#        [0.95587008],
#        [1.01558597],
#        [1.01345543],
#        [0.95053742],
#        [1.0097536 ],
#        [0.97210992],
#        [0.98224041],
#        [1.04193398],
#        [1.04426981],
#        [1.02272641],
#        [1.01569378],
#        [1.01828445],
#        [1.03590943],
#        [0.96554822],
#        [1.03350835],
#        [1.06092297],
#        [1.0576234 ],
#        [1.03997474],
#        [1.11441306],
#        [1.0260518 ],
#        [1.04732082],
#        [0.95708873],
#        [0.96839852],
#        [0.94005503],
#        [0.97872314],
#        [1.02740615],
#        [0.95679057],
#        [1.01381791],
#        [0.99446321],
#        [0.87571497],
#        [1.0007616 ],
#        [1.05591098]]), 'Wo': array([[-0.07029353,  0.08007363, -0.11357934, ...,  0.07795353,
#          0.10019695,  0.08088321],
#        [ 0.15905675,  0.09932922, -0.10309724, ...,  0.02991522,
#          0.05857103,  0.04865553],
#        [-0.29251172, -0.05999288, -0.27306726, ..., -0.03054881,
#          0.1350382 ,  0.14812509],
#        ...,
#        [ 0.08772661,  0.10673849, -0.00115548, ...,  0.04290671,
#          0.06545332,  0.0763722 ],
#        [ 0.04237087, -0.08847114, -0.13073105, ..., -0.20042277,
#          0.1409413 ,  0.11217493],
#        [-0.00465607, -0.04759776,  0.09463798, ...,  0.07904445,
#         -0.17132684, -0.08295297]]), 'bo': array([[1.08483459],
#        [1.01442682],
#        [1.05505123],
#        [1.06302764],
#        [1.01167186],
#        [1.07951384],
#        [0.94896253],
#        [0.99405769],
#        [0.98760615],
#        [1.08418421],
#        [1.05841547],
#        [1.04842251],
#        [1.00759666],
#        [1.05535328],
#        [1.00678728],
#        [0.99191856],
#        [1.05720347],
#        [1.02658226],
#        [1.01987389],
#        [1.02017922],
#        [1.02790269],
#        [0.91845656],
#        [0.96300877],
#        [1.0788484 ],
#        [0.96535852],
#        [1.07945143],
#        [1.06165371],
#        [1.10206712],
#        [1.04604272],
#        [0.99262183],
#        [1.04192852],
#        [0.94856452],
#        [1.01057044],
#        [1.0526348 ],
#        [1.00750781],
#        [1.03677126],
#        [1.09536193],
#        [1.03911276],
#        [0.99722213],
#        [1.03709059],
#        [1.10294905],
#        [1.08686586],
#        [1.12098127],
#        [0.9799658 ],
#        [1.03306697],
#        [1.08063732],
#        [0.96981011],
#        [0.90780337],
#        [1.0869364 ],
#        [1.03806227],
#        [1.03582956],
#        [0.96907334],
#        [1.07658574],
#        [1.00371491],
#        [1.07048012],
#        [1.0667711 ],
#        [0.98352455],
#        [1.10008805],
#        [1.02106115],
#        [0.94118526],
#        [1.02049945],
#        [1.06117039],
#        [0.99869695],
#        [1.00320191],
#        [1.02055282],
#        [0.99612243],
#        [1.10574692],
#        [0.99426786],
#        [1.02786473],
#        [0.98043052],
#        [1.11625467],
#        [1.02060557],
#        [1.00993411],
#        [1.09183542],
#        [1.05379105],
#        [0.9777543 ],
#        [0.96852636],
#        [1.01553117],
#        [1.03125061],
#        [0.97970334],
#        [0.99001403],
#        [1.08278532],
#        [0.94347595],
#        [0.97013913],
#        [0.99236927],
#        [1.08182622],
#        [1.00267792],
#        [1.05509985],
#        [0.98642501],
#        [1.04115096],
#        [1.00331833],
#        [0.91396723],
#        [1.07651437],
#        [1.07237476],
#        [0.99770155],
#        [1.01506561],
#        [1.11002575],
#        [1.07522041],
#        [1.04765811],
#        [0.95166721]]), 'Wv': array([[-0.2386224 , -0.1976348 ,  1.51062579, ...,  0.15778947,
#          1.06544564, -0.12085933],
#        [-0.24415036, -0.29229287,  1.44721086, ...,  0.19354405,
#          0.89592646, -0.11803306],
#        [-0.24768419, -0.25671892,  1.33293496, ...,  0.18161202,
#          0.84000461, -0.2121622 ],
#        ...,
#        [-0.11290737, -0.73869952,  0.73516966, ..., -0.07864911,
#          0.59908019, -1.3404457 ],
#        [-0.15103016, -0.83785009,  0.70159712, ..., -0.08537597,
#          0.60404033, -1.48183735],
#        [-0.26021935, -0.56292417,  0.76060349, ..., -0.07318763,
#          0.45957438, -0.76048585]]), 'bv': array([[ 0.55189864],
#        [ 0.54922417],
#        [ 0.51973127],
#        [ 0.51256282],
#        [ 0.50053639],
#        [ 0.5002098 ],
#        [ 0.49118749],
#        [ 0.54254183],
#        [ 0.50415519],
#        [ 0.53172128],
#        [ 0.52079947],
#        [ 0.53918812],
#        [ 0.56816354],
#        [ 0.5326313 ],
#        [ 0.59617085],
#        [ 0.56252291],
#        [ 0.59518584],
#        [ 0.58227777],
#        [ 0.64526329],
#        [ 0.6213892 ],
#        [ 0.59747438],
#        [ 0.62027923],
#        [ 0.62259522],
#        [ 0.60561448],
#        [ 0.59368882],
#        [ 0.56752739],
#        [ 0.55787008],
#        [ 0.53089869],
#        [ 0.51498567],
#        [ 0.49288713],
#        [ 0.48849207],
#        [ 0.4636246 ],
#        [ 0.47320018],
#        [ 0.46288856],
#        [ 0.4626002 ],
#        [ 0.46995555],
#        [ 0.46717562],
#        [ 0.47840668],
#        [ 0.49168483],
#        [ 0.48868243],
#        [ 0.47734584],
#        [ 0.48016398],
#        [ 0.47598396],
#        [ 0.47113257],
#        [ 0.44080329],
#        [ 0.4421051 ],
#        [ 0.40831304],
#        [ 0.42784808],
#        [ 0.37786855],
#        [ 0.35817532],
#        [ 0.36805481],
#        [ 0.36292784],
#        [ 0.33541225],
#        [ 0.32845705],
#        [ 0.28048248],
#        [ 0.23400518],
#        [ 0.1819498 ],
#        [ 0.18886013],
#        [ 0.16269289],
#        [ 0.16321538],
#        [ 0.11933747],
#        [ 0.12267769],
#        [ 0.10109346],
#        [ 0.07707441],
#        [ 0.04868918],
#        [ 0.04872541],
#        [ 0.02599036],
#        [ 0.00274455],
#        [ 0.00214734],
#        [ 0.01488596],
#        [-0.00264986],
#        [-0.01427478],
#        [ 0.00837774],
#        [-0.02074682],
#        [-0.01881659],
#        [-0.03379416],
#        [-0.03887706],
#        [-0.08588603],
#        [-0.06599652],
#        [-0.09646249],
#        [-0.10248796],
#        [-0.12767899],
#        [-0.14180263],
#        [-0.14824418],
#        [-0.17352435],
#        [-0.16810656],
#        [-0.20085508],
#        [-0.21013467],
#        [-0.20077239],
#        [-0.21941318],
#        [-0.23137729],
#        [-0.26626499],
#        [-0.2540237 ],
#        [-0.2579765 ],
#        [-0.27554517],
#        [-0.277851  ],
#        [-0.29158627],
#        [-0.29255974],
#        [-0.30855943],
#        [-0.28638549],
#        [-0.49234609]])}]
